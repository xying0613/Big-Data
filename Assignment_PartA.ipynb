# %% [markdown]
# Name: Haw Xiao Ying <br>Student ID: 29797918 <br>Email: xhaw0001@student.monash.edu

# %% [markdown]
# # Assignment Part A

# %% [markdown]
# ## Task 1: MongoDB Data Model

# %% [markdown]
# Based on `hotspot_historic.csv` and `climate_historic.csv`, I have decided to use the **Referencing Data Model** over Embedded Data Model to support the efficient querying of these two datasets in MongoDB.
#
#
# Here is an example of the **Referencing Data Model**:
#
# - Student Collection:
# {
#     '_id': ObjectId('60a1fc95c3ea69575a867047'),
#     'stu_id': "29797918"
# }
#
# - Personal details Collection:
# {
#     '_id': ObjectId('60a1fc95c3ea69575a867048'),
#     'foreign_key': "ObjectId('60a1fc95c3ea69575a867047')",
#     'family_name': "Haw",
#     'given_name': "Xiao Ying",
#     'dob': "2000-06-13"
# }
#
#
# Example of Referencing Data Model used in this assignment:
# - Climate Collection:
# {
#     '_id': ObjectId('60a1fc95c3ea69575a867047'),
#     'date': '2018-03-06', 'station': 948702,
#     'air_temperature_celcius': 19,
#     'relative_humidity': 52.9,
#     'windspeed_knots': 8.1,
#     'max_wind_speed': 15.0,
#     'precipitation ': ' 0.00I',
#     'GHI_w/m2': 159
# }
#
# - Hotspot Collection:
# {
#     '_id': ObjectId('60a3c91b1b38980f0d0c7384'),
#     'foreign_key': ObjectId('60a1fc95c3ea69575a867047'),
#     'date': '2018-03-06',
#     'latitude': -34.3735,
#     'longitude': 141.6604,
#     'datetime': '2018-03-06T05:06:20',
#     'confidence': 85,
#     'surface_temperature_celcius': 59
# }
#
#
#
# Since we are going to query data in many different ways, it would be better if my model is a more normalized approach as it would be more flexible. Moreover, Embedded Data Model provides the benefit of updating the data in a single seek but since we are only going to query the data in the next task, increased flexibility in querying data is more useful and beneficial for us. In this assignment, ObjectID of climate_historic acts as the foreign key.

# %% [markdown]
# ## Task 2: Querying MongoDB using PyMongo

# %% [markdown]
# ### 1. Read data and load into database: fit3182_assignment_db

# %%
import pymongo, csv
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime


# Connect on the default host and port
client = MongoClient () 

# Drop database if it originally exist
client.drop_database('fit3182_assignment_db')

# Create database
db = client.fit3182_assignment_db

# Drop collection if they exist
db.hotspot_historic.drop()
db.climate_historic.drop()

# Collection of hotspot and climate since I'm using Referencing
hotspot = db.hotspot_historic
climate = db.climate_historic

# Read csv file
hotspot_historic_filepath = 'C:/Users/User/Documents/FIT3182/Assignment/hotspot_historic.csv'
climate_historic_filepath = 'C:/Users/User/Documents/FIT3182/Assignment/climate_historic.csv'
        
header = ["station", "air_temperature_celcius", "relative_humidity",
          "windspeed_knots", "max_wind_speed", "precipitation ", "GHI_w/m2"]
with open(climate_historic_filepath) as file:
    climate_csv = csv.DictReader(file)
    for each_row in climate_csv:
        row = {}
        row["date"] = str(datetime.strptime(each_row["date"], '%d/%m/%y'))[:10]
        for col in header:
            if col in ["date","precipitation "]:
                row[col] = each_row[col]
            elif col in ["station", "air_temperature_celcius", "GHI_w/m2"]:
                row[col] = int(each_row[col])
            else:
                row[col] = float(each_row[col])
        db.climate.insert_one(row)
    print("Sample of data inserted (climate):", row)
    

header = ["latitude", "longitude", "datetime", "confidence", "surface_temperature_celcius"]
with open(hotspot_historic_filepath) as file:
    hotspot_csv = csv.DictReader(file)
    for each_row in hotspot_csv:
        row = {}
        row["date"] = str(datetime.strptime(each_row["date"], '%d/%m/%Y'))[:10]
        for col in header:
            if col in ["datetime", "date"]:
                row[col] = each_row[col]
            elif col in ["latitude", "longitude"]:
                row[col] = float(each_row[col])
            else:
                row[col] = int(each_row[col])
                
        cursor = db.climate.find({"date" : row["date"]})
        row["foreign_key"] = cursor[0]["_id"]
        
        db.hotspot.insert_one(row)
    print("\nSample of data inserted (hotspot):", row)
# Out:
# Sample of data inserted (climate): {'date': '2018-01-01', 'station': 948702, 'air_temperature_celcius': 19, 'relative_humidity': 52.9, 'windspeed_knots': 8.1, 'max_wind_speed': 15.0, 'precipitation ': ' 0.00I', 'GHI_w/m2': 159, '_id': ObjectId('60af2db45f8d21aa9c54d67e')}
#
# Sample of data inserted (hotspot): {'date': '2018-03-06', 'latitude': -34.3735, 'longitude': 141.6604, 'datetime': '2018-03-06T05:06:20', 'confidence': 85, 'surface_temperature_celcius': 59, 'foreign_key': ObjectId('60af2db45f8d21aa9c54d551'), '_id': ObjectId('60af2dba5f8d21aa9c54e0ea')}

# %% [markdown]
# ### 2. Write queries

# %%
# a. Find climate data on 12th December 2018.

cursor = db.climate.find({'date': '2018-12-12'})
for item in cursor:
    pprint(item)
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af2db45f8d21aa9c54d66a'),
#  'air_temperature_celcius': 19,
#  'date': '2018-12-12',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %%
# b. Find the latitude, longitude, surface temperature (°C), and confidence 
#    when the surface temperature (°C) was between 65 °C and 100 °C.

cursor = db.hotspot.find({"surface_temperature_celcius" : { "$gte":65, "$lte":100}}, 
                         {'latitude':1, 'longitude':1, 'confidence':1, 'surface_temperature_celcius':1, '_id':0})

for item in cursor:
    pprint(item)
    print('\n')
# Out:
# {'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 90,
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'latitude': -37.462,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.081,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 100,
#  'latitude': -37.401,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 92,
#  'latitude': -36.663,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 92,
#  'latitude': -36.803,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.272,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
#
#
# {'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 93,
#  'latitude': -36.388,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.538,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.978,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 93,
#  'latitude': -36.663,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
#
#
# {'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
#
#
# {'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
#
#
# {'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
#
#
# {'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 100,
#  'latitude': -36.4409,
#  'longitude': 141.6948,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 100,
#  'latitude': -37.9174,
#  'longitude': 145.8678,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 95,
#  'latitude': -37.9152,
#  'longitude': 145.8808,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 95,
#  'latitude': -37.8906,
#  'longitude': 146.2035,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'latitude': -35.8182,
#  'longitude': 143.8739,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 100,
#  'latitude': -37.9246,
#  'longitude': 146.2464,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 94,
#  'latitude': -36.3313,
#  'longitude': 141.0017,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 90,
#  'latitude': -36.2857,
#  'longitude': 141.3467,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 92,
#  'latitude': -36.0749,
#  'longitude': 143.4058,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 91,
#  'latitude': -36.4449,
#  'longitude': 140.9836,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'latitude': -36.3972,
#  'longitude': 141.6041,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 90,
#  'latitude': -36.5532,
#  'longitude': 142.5349,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 92,
#  'latitude': -36.1367,
#  'longitude': 145.2071,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 96,
#  'latitude': -36.1518,
#  'longitude': 144.0233,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 95,
#  'latitude': -36.1418,
#  'longitude': 144.0261,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 94,
#  'latitude': -37.5812,
#  'longitude': 142.7374,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'latitude': -37.5949,
#  'longitude': 142.6857,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 95,
#  'latitude': -37.8247,
#  'longitude': 143.6243,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 95,
#  'latitude': -37.4028,
#  'longitude': 143.6932,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 92,
#  'latitude': -37.4033,
#  'longitude': 143.6884,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -37.8249,
#  'longitude': 143.6174,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 93,
#  'latitude': -36.6823,
#  'longitude': 142.5024,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 93,
#  'latitude': -36.4489,
#  'longitude': 144.7685,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 67,
#  'latitude': -37.34,
#  'longitude': 149.3668,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 99,
#  'latitude': -36.7287,
#  'longitude': 142.6017,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 91,
#  'latitude': -35.2363,
#  'longitude': 143.0004,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 100,
#  'latitude': -35.2378,
#  'longitude': 142.9864,
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 98,
#  'latitude': -35.2381,
#  'longitude': 142.994,
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 66,
#  'latitude': -37.3493,
#  'longitude': 149.3691,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 90,
#  'latitude': -36.7165,
#  'longitude': 142.6155,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 100,
#  'latitude': -37.2168,
#  'longitude': 147.4748,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 96,
#  'latitude': -37.222,
#  'longitude': 147.4689,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 92,
#  'latitude': -37.2063,
#  'longitude': 147.4713,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 92,
#  'latitude': -37.2082,
#  'longitude': 147.4368,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 95,
#  'latitude': -37.224,
#  'longitude': 147.4347,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 84,
#  'latitude': -37.5816,
#  'longitude': 148.5862,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 92,
#  'latitude': -36.6334,
#  'longitude': 142.2244,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 76,
#  'latitude': -37.7966,
#  'longitude': 142.3196,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 100,
#  'latitude': -35.805,
#  'longitude': 142.1326,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 100,
#  'latitude': -37.8429,
#  'longitude': 143.8366,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 77,
#  'latitude': -37.8062,
#  'longitude': 143.3598,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'latitude': -36.9918,
#  'longitude': 141.8667,
#  'surface_temperature_celcius': 97}
#
#
# {'confidence': 90,
#  'latitude': -36.1104,
#  'longitude': 145.9829,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 83,
#  'latitude': -37.803,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.081,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
#
#
# {'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.913,
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
#
#
# {'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
#
#
# {'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
#
#
# {'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.728,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.897,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
#
#
# {'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.027,
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}

# %%
# c. Find date, surface temperature (°C), air temperature (°C), relative humidity 
#    and max wind speed on 15th and 16th of December 2018.

cursor = db.climate.aggregate([
    {"$lookup" : {
        "from" : "hotspot",
        "localField": "_id",
        "foreignField": "foreign_key",
        "as": "from_hotspot_historic"
        }},
    
    {"$match" : {
        "$or": [{'date':'2018-12-15'}, {'date':'2018-12-16'}]
        }},
    
    {"$project" : {
        'air_temperature_celcius':1, 
        'date':1, 
        'relative_humidity':1, 
        'max_wind_speed':1, 
        '_id':0,
        'from_hotspot_historic' : {
            'surface_temperature_celcius':1
        }}}
    ])

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'air_temperature_celcius': 18,
#  'date': '2018-12-15',
#  'from_hotspot_historic': [{'surface_temperature_celcius': 42},
#                            {'surface_temperature_celcius': 36},
#                            {'surface_temperature_celcius': 38},
#                            {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
#
#
# {'air_temperature_celcius': 18,
#  'date': '2018-12-16',
#  'from_hotspot_historic': [{'surface_temperature_celcius': 43},
#                            {'surface_temperature_celcius': 33},
#                            {'surface_temperature_celcius': 54},
#                            {'surface_temperature_celcius': 73},
#                            {'surface_temperature_celcius': 55},
#                            {'surface_temperature_celcius': 75},
#                            {'surface_temperature_celcius': 55},
#                            {'surface_temperature_celcius': 66},
#                            {'surface_temperature_celcius': 56},
#                            {'surface_temperature_celcius': 60},
#                            {'surface_temperature_celcius': 73},
#                            {'surface_temperature_celcius': 48},
#                            {'surface_temperature_celcius': 55},
#                            {'surface_temperature_celcius': 64},
#                            {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
# d. Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.

cursor = db.hotspot.aggregate([
    {"$lookup" : {
        "from" : "climate",
        "localField": "foreign_key",
        "foreignField": "_id",
        "as": "from_climate_historic"
        }},
    
    {"$match" : {
        'confidence' : {"$gte":80, "$lte":100}
        }},
    
    {"$project" : {
        'confidence':1, 
        'datetime':1, 
        'surface_temperature_celcius':1,
        '_id':0,
        'from_climate_historic' : {
            'air_temperature_celcius':1
        }}}
    ])

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'confidence': 82,
#  'datetime': '2018-12-27T00:02:15',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 86,
#  'datetime': '2018-12-27T00:02:14',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 80,
#  'datetime': '2018-12-25T04:29:08',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 94,
#  'datetime': '2018-12-16T15:38:39',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 43}
#
#
# {'confidence': 93,
#  'datetime': '2018-12-16T04:35:13',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 84,
#  'datetime': '2018-12-16T04:34:58',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 95,
#  'datetime': '2018-12-16T04:34:58',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 90,
#  'datetime': '2018-12-16T04:34:57',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 93,
#  'datetime': '2018-12-16T00:21:12',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 82,
#  'datetime': '2018-12-16T00:21:11',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 82,
#  'datetime': '2018-12-16T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 92,
#  'datetime': '2018-12-15T13:17:17',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 42}
#
#
# {'confidence': 92,
#  'datetime': '2018-12-14T04:47:25',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 83,
#  'datetime': '2018-12-13T04:04:19',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 87,
#  'datetime': '2018-12-09T00:14:34',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 81,
#  'datetime': '2018-12-09T00:14:34',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 84,
#  'datetime': '2018-12-09T00:14:33',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 86,
#  'datetime': '2018-12-09T00:14:33',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-12-08T13:11:44',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 100,
#  'datetime': '2018-12-08T13:11:44',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'datetime': '2018-12-08T13:11:43',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T15:38:36',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T15:38:35',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T15:38:35',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 49}
#
#
# {'confidence': 84,
#  'datetime': '2018-11-30T12:22:15',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 38}
#
#
# {'confidence': 81,
#  'datetime': '2018-11-30T12:22:15',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 42}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T12:22:15',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T12:22:15',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-30T12:22:14',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 84,
#  'datetime': '2018-11-30T04:35:00',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 98,
#  'datetime': '2018-11-30T04:34:57',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 81,
#  'datetime': '2018-11-30T04:34:57',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 84,
#  'datetime': '2018-11-30T04:34:57',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 99,
#  'datetime': '2018-11-30T04:34:57',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 83,
#  'datetime': '2018-11-30T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 87,
#  'datetime': '2018-11-30T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 95,
#  'datetime': '2018-11-30T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 81,
#  'datetime': '2018-11-30T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 81,
#  'datetime': '2018-11-30T00:20:53',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-29T13:17:24',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-29T03:52:10',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 97,
#  'datetime': '2018-11-29T03:52:10',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 99,
#  'datetime': '2018-11-29T03:52:10',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 84,
#  'datetime': '2018-11-23T04:28:59',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 93,
#  'datetime': '2018-11-23T04:28:59',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 84,
#  'datetime': '2018-11-22T03:46:00',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 88,
#  'datetime': '2018-11-22T03:46:00',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 85,
#  'datetime': '2018-11-21T00:27:21',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 87,
#  'datetime': '2018-11-14T04:35:04',
#  'from_climate_historic': [{'air_temperature_celcius': 28}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 87,
#  'datetime': '2018-11-13T03:52:15',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 81,
#  'datetime': '2018-11-13T03:52:14',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 89,
#  'datetime': '2018-11-12T00:33:15',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 80,
#  'datetime': '2018-11-11T13:30:08',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 37}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-11T13:30:08',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 86,
#  'datetime': '2018-11-11T04:04:25',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 85,
#  'datetime': '2018-11-09T04:16:48',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 100,
#  'datetime': '2018-11-09T04:16:48',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 96,
#  'datetime': '2018-11-09T04:16:48',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 87,
#  'datetime': '2018-11-09T04:16:44',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 97,
#  'datetime': '2018-11-09T04:16:44',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 83,
#  'datetime': '2018-11-05T04:41:34',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 90,
#  'datetime': '2018-11-05T04:41:19',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 89,
#  'datetime': '2018-11-05T04:41:19',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 81,
#  'datetime': '2018-10-28T03:52:17',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 86,
#  'datetime': '2018-10-27T04:47:31',
#  'from_climate_historic': [{'air_temperature_celcius': 22}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-10-26T13:30:31',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 100,
#  'datetime': '2018-10-26T13:30:31',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 88,
#  'datetime': '2018-10-21T01:09:55',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 92,
#  'datetime': '2018-10-21T01:09:54',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 80,
#  'datetime': '2018-10-20T04:41:19',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 46}
#
#
# {'confidence': 82,
#  'datetime': '2018-10-20T04:41:19',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 50}
#
#
# {'confidence': 84,
#  'datetime': '2018-10-18T00:39:02',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 82,
#  'datetime': '2018-10-18T00:39:02',
#  'from_climate_historic': [{'air_temperature_celcius': 26}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 94,
#  'datetime': '2018-10-17T13:36:12',
#  'from_climate_historic': [{'air_temperature_celcius': 22}],
#  'surface_temperature_celcius': 43}
#
#
# {'confidence': 91,
#  'datetime': '2018-10-17T04:10:45',
#  'from_climate_historic': [{'air_temperature_celcius': 22}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 82,
#  'datetime': '2018-10-17T04:10:32',
#  'from_climate_historic': [{'air_temperature_celcius': 22}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 100,
#  'datetime': '2018-10-15T04:23:01',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 99,
#  'datetime': '2018-10-15T04:23:01',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 96,
#  'datetime': '2018-10-10T04:04:19',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 91,
#  'datetime': '2018-10-07T12:59:33',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 42}
#
#
# {'confidence': 80,
#  'datetime': '2018-10-04T04:41:02',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 46}
#
#
# {'confidence': 80,
#  'datetime': '2018-10-04T04:41:00',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 46}
#
#
# {'confidence': 85,
#  'datetime': '2018-10-04T04:41:00',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 88,
#  'datetime': '2018-10-04T04:41:00',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 92,
#  'datetime': '2018-10-03T13:23:43',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 42}
#
#
# {'confidence': 90,
#  'datetime': '2018-10-03T03:58:15',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 81,
#  'datetime': '2018-10-03T03:58:15',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 82,
#  'datetime': '2018-10-03T03:58:15',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 49}
#
#
# {'confidence': 84,
#  'datetime': '2018-10-03T03:58:15',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 90,
#  'datetime': '2018-10-03T03:58:15',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 100,
#  'datetime': '2018-10-03T03:58:14',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 88,
#  'datetime': '2018-10-03T03:58:14',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 87,
#  'datetime': '2018-10-03T03:58:14',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 83,
#  'datetime': '2018-10-02T04:53:10',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 50}
#
#
# {'confidence': 85,
#  'datetime': '2018-10-02T04:53:09',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 100,
#  'datetime': '2018-10-01T15:13:56',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 84,
#  'datetime': '2018-10-01T04:10:28',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 89,
#  'datetime': '2018-10-01T04:10:28',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 82,
#  'datetime': '2018-09-29T04:22:31',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 49}
#
#
# {'confidence': 83,
#  'datetime': '2018-09-27T04:35:36',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 86,
#  'datetime': '2018-09-27T04:35:36',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T15:07:47',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 90,
#  'datetime': '2018-09-24T15:07:47',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 41}
#
#
# {'confidence': 99,
#  'datetime': '2018-09-24T15:07:47',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 94,
#  'datetime': '2018-09-24T15:07:45',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 43}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T15:07:45',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T13:30:10',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 47}
#
#
# {'confidence': 82,
#  'datetime': '2018-09-24T13:30:09',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 38}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T13:30:09',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T13:30:09',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 84,
#  'datetime': '2018-09-24T13:30:07',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 50}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-24T04:04:19',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 86,
#  'datetime': '2018-09-24T04:04:18',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 84,
#  'datetime': '2018-09-24T04:04:04',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 86,
#  'datetime': '2018-09-23T23:50:44',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 50}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-23T12:47:12',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 88,
#  'datetime': '2018-09-23T04:59:13',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 87,
#  'datetime': '2018-09-23T04:59:11',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 80,
#  'datetime': '2018-09-23T04:59:11',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 50}
#
#
# {'confidence': 89,
#  'datetime': '2018-09-20T04:29:03',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-09-20T04:29:03',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 112}
#
#
# {'confidence': 88,
#  'datetime': '2018-09-20T04:28:45',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 80,
#  'datetime': '2018-09-10T04:00:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 84,
#  'datetime': '2018-09-10T03:53:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 86,
#  'datetime': '2018-09-10T03:50:30',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 81,
#  'datetime': '2018-09-10T03:50:10',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 87,
#  'datetime': '2018-08-13T05:08:00',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 80,
#  'datetime': '2018-08-13T05:05:10',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 83,
#  'datetime': '2018-08-13T05:02:30',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 94,
#  'datetime': '2018-08-02T03:45:40',
#  'from_climate_historic': [{'air_temperature_celcius': 5}],
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 89,
#  'datetime': '2018-08-01T00:20:30',
#  'from_climate_historic': [{'air_temperature_celcius': 7}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'datetime': '2018-07-31T13:21:00',
#  'from_climate_historic': [{'air_temperature_celcius': 7}],
#  'surface_temperature_celcius': 51}
#
#
# {'confidence': 92,
#  'datetime': '2018-07-31T13:21:00',
#  'from_climate_historic': [{'air_temperature_celcius': 7}],
#  'surface_temperature_celcius': 43}
#
#
# {'confidence': 83,
#  'datetime': '2018-07-06T04:08:00',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 91,
#  'datetime': '2018-07-06T04:02:00',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 84,
#  'datetime': '2018-07-02T04:29:18',
#  'from_climate_historic': [{'air_temperature_celcius': 6}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 84,
#  'datetime': '2018-07-02T04:29:18',
#  'from_climate_historic': [{'air_temperature_celcius': 6}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 88,
#  'datetime': '2018-07-02T04:29:00',
#  'from_climate_historic': [{'air_temperature_celcius': 6}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 88,
#  'datetime': '2018-07-02T04:29:00',
#  'from_climate_historic': [{'air_temperature_celcius': 6}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 81,
#  'datetime': '2018-06-30T00:27:19',
#  'from_climate_historic': [{'air_temperature_celcius': 5}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 81,
#  'datetime': '2018-06-30T00:27:19',
#  'from_climate_historic': [{'air_temperature_celcius': 5}],
#  'surface_temperature_celcius': 48}
#
#
# {'confidence': 91,
#  'datetime': '2018-06-20T04:02:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'datetime': '2018-06-20T04:02:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 88}
#
#
# {'confidence': 97,
#  'datetime': '2018-06-20T04:02:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 100,
#  'datetime': '2018-06-20T04:02:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 94,
#  'datetime': '2018-06-14T04:43:00',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 84,
#  'datetime': '2018-06-09T04:23:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 52}
#
#
# {'confidence': 86,
#  'datetime': '2018-06-09T04:23:16',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 86,
#  'datetime': '2018-06-07T04:35:50',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 96,
#  'datetime': '2018-06-07T04:33:50',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 85,
#  'datetime': '2018-06-07T04:32:10',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 81,
#  'datetime': '2018-06-07T04:32:10',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 85,
#  'datetime': '2018-06-07T04:32:10',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 90,
#  'datetime': '2018-06-07T04:32:10',
#  'from_climate_historic': [{'air_temperature_celcius': 8}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 86,
#  'datetime': '2018-06-04T04:08:20',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 91,
#  'datetime': '2018-06-04T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 91,
#  'datetime': '2018-06-04T04:02:10',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 85,
#  'datetime': '2018-06-04T04:02:10',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 83,
#  'datetime': '2018-06-02T04:14:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 83,
#  'datetime': '2018-06-02T04:14:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 82,
#  'datetime': '2018-06-01T05:09:20',
#  'from_climate_historic': [{'air_temperature_celcius': 11}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-26T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 13}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-23T00:58:00',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-23T00:54:50',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-22T04:43:30',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-22T04:34:10',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 101}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-22T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-22T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 98,
#  'datetime': '2018-05-22T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-22T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 89,
#  'datetime': '2018-05-22T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-22T00:15:00',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-22T00:13:00',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 89,
#  'datetime': '2018-05-22T00:13:00',
#  'from_climate_historic': [{'air_temperature_celcius': 17}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 93,
#  'datetime': '2018-05-15T04:34:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-15T04:34:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-15T04:33:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 92,
#  'datetime': '2018-05-15T04:33:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T04:32:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 101}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-15T04:32:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-15T04:31:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-15T04:31:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-15T04:30:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-15T04:29:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-15T04:29:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T04:28:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 94}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-15T04:28:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T04:28:00',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 87}
#
#
# {'confidence': 90,
#  'datetime': '2018-05-15T04:27:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 89,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 111}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 90,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 90,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 94,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 110}
#
#
# {'confidence': 89,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 95,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 94,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-15T04:26:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-15T00:12:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:45:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 102}
#
#
# {'confidence': 95,
#  'datetime': '2018-05-13T04:43:30',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:41:50',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:40:20',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 120}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:40:10',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-13T04:39:50',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-13T04:39:30',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-13T04:39:00',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:38:50',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 93}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 94,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 113}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 90,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 95}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-13T04:38:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-12T03:57:40',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 93,
#  'datetime': '2018-05-12T03:56:10',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-12T03:56:10',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 90,
#  'datetime': '2018-05-11T04:57:20',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-11T04:57:20',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 88,
#  'datetime': '2018-05-11T04:54:00',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 89,
#  'datetime': '2018-05-11T04:51:00',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 94,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 92,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 99,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 69}
#
#
# {'confidence': 97,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-11T04:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 9}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-10T04:16:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-10T04:16:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 88,
#  'datetime': '2018-05-10T04:14:20',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-10T04:14:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 103}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-10T04:12:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-10T04:12:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-10T04:11:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-10T04:11:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-10T04:11:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-10T04:08:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 98,
#  'datetime': '2018-05-10T04:08:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 98,
#  'datetime': '2018-05-10T04:08:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-10T04:08:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 92,
#  'datetime': '2018-05-10T04:08:50',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-10T04:08:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-10T04:08:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-10T04:08:30',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 95,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 99,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 84}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 92,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 113}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 84,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 96,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 78}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 94,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 82,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 85,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 99,
#  'datetime': '2018-05-10T04:08:10',
#  'from_climate_historic': [{'air_temperature_celcius': 10}],
#  'surface_temperature_celcius': 85}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-09T12:56:40',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 39}
#
#
# {'confidence': 81,
#  'datetime': '2018-05-09T05:02:50',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 93,
#  'datetime': '2018-05-08T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 87,
#  'datetime': '2018-05-08T04:24:00',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 80,
#  'datetime': '2018-05-08T04:20:40',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 83,
#  'datetime': '2018-05-08T04:20:20',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 86,
#  'datetime': '2018-05-08T04:20:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-08T04:20:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-08T04:20:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 101}
#
#
# {'confidence': 100,
#  'datetime': '2018-05-08T04:20:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 115}
#
#
# {'confidence': 97,
#  'datetime': '2018-05-08T04:20:10',
#  'from_climate_historic': [{'air_temperature_celcius': 12}],
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 91,
#  'datetime': '2018-05-06T04:39:00',
# ...
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 80,
#  'datetime': '2018-04-03T03:51:00',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 100,
#  'datetime': '2018-04-03T03:51:00',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 103}
#
#
# {'confidence': 87,
#  'datetime': '2018-04-03T03:50:50',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 97}
#
#
# {'confidence': 90,
#  'datetime': '2018-04-03T03:50:50',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 85,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 99,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 93,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 95,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 86,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 89,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 82,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 89,
#  'datetime': '2018-04-03T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 81,
#  'datetime': '2018-04-03T01:07:20',
#  'from_climate_historic': [{'air_temperature_celcius': 15}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 82,
#  'datetime': '2018-03-31T05:07:10',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-31T05:01:20',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 82,
#  'datetime': '2018-03-31T04:58:30',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 80,
#  'datetime': '2018-03-31T04:58:00',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 86,
#  'datetime': '2018-03-31T04:57:10',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 61}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-31T00:36:30',
#  'from_climate_historic': [{'air_temperature_celcius': 14}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 88,
#  'datetime': '2018-03-28T04:38:00',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 86,
#  'datetime': '2018-03-28T04:33:40',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 92,
#  'datetime': '2018-03-28T04:33:30',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 95,
#  'datetime': '2018-03-28T04:33:30',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 76}
#
#
# {'confidence': 93,
#  'datetime': '2018-03-28T04:32:20',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 83,
#  'datetime': '2018-03-28T04:30:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 56}
#
#
# {'confidence': 80,
#  'datetime': '2018-03-28T04:30:20',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 94,
#  'datetime': '2018-03-28T04:30:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 98,
#  'datetime': '2018-03-28T04:30:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 82}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-28T04:30:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-28T04:30:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-28T04:28:30',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 88,
#  'datetime': '2018-03-28T04:28:30',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-28T04:28:30',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-28T04:27:40',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-28T04:27:20',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 107}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-28T04:27:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 108}
#
#
# {'confidence': 82,
#  'datetime': '2018-03-28T04:27:00',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 99,
#  'datetime': '2018-03-28T04:27:00',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 86}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 80,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 83,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 90}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 88,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 63}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 84,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 81}
#
#
# {'confidence': 83,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 57}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-28T04:26:50',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-26T04:43:20',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 80,
#  'datetime': '2018-03-26T04:40:50',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 53}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-26T04:39:50',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 54}
#
#
# {'confidence': 91,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 92,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 89}
#
#
# {'confidence': 82,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 84,
#  'datetime': '2018-03-26T04:39:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 82,
#  'datetime': '2018-03-25T03:59:50',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-25T03:58:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 95,
#  'datetime': '2018-03-25T03:58:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-25T03:57:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-25T03:57:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 111}
#
#
# {'confidence': 95,
#  'datetime': '2018-03-25T03:57:10',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 77}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-25T03:56:40',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-19T04:39:50',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 96,
#  'datetime': '2018-03-19T04:39:20',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 90,
#  'datetime': '2018-03-19T04:36:00',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 66}
#
#
# {'confidence': 98,
#  'datetime': '2018-03-19T04:33:00',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 83}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-19T04:32:50',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 91}
#
#
# {'confidence': 84,
#  'datetime': '2018-03-19T04:32:50',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 58}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-19T04:32:40',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 113}
#
#
# {'confidence': 92,
#  'datetime': '2018-03-19T04:32:40',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 70}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-19T04:32:40',
#  'from_climate_historic': [{'air_temperature_celcius': 24}],
#  'surface_temperature_celcius': 106}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-18T03:50:50',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 121}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-18T03:50:40',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 94,
#  'datetime': '2018-03-17T04:48:20',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 74}
#
#
# {'confidence': 84,
#  'datetime': '2018-03-17T04:45:10',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 59}
#
#
# {'confidence': 86,
#  'datetime': '2018-03-17T04:45:00',
#  'from_climate_historic': [{'air_temperature_celcius': 18}],
#  'surface_temperature_celcius': 60}
#
#
# {'confidence': 90,
#  'datetime': '2018-03-14T04:24:40',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 67}
#
#
# {'confidence': 93,
#  'datetime': '2018-03-14T04:22:20',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 72}
#
#
# {'confidence': 90,
#  'datetime': '2018-03-14T04:20:50',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 95,
#  'datetime': '2018-03-14T04:16:30',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 89,
#  'datetime': '2018-03-14T04:16:20',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 65}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-14T04:14:40',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 96,
#  'datetime': '2018-03-14T04:14:30',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 79}
#
#
# {'confidence': 94,
#  'datetime': '2018-03-14T04:14:30',
#  'from_climate_historic': [{'air_temperature_celcius': 25}],
#  'surface_temperature_celcius': 75}
#
#
# {'confidence': 94,
#  'datetime': '2018-03-12T04:33:50',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 105}
#
#
# {'confidence': 84,
#  'datetime': '2018-03-12T04:29:50',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 71}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-12T04:28:20',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 99}
#
#
# {'confidence': 80,
#  'datetime': '2018-03-12T04:28:00',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 68}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-12T04:27:20',
#  'from_climate_historic': [{'air_temperature_celcius': 21}],
#  'surface_temperature_celcius': 98}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-10T04:48:40',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 105}
#
#
# {'confidence': 100,
#  'datetime': '2018-03-10T04:46:20',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 109}
#
#
# {'confidence': 94,
#  'datetime': '2018-03-10T04:45:30',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 73}
#
#
# {'confidence': 97,
#  'datetime': '2018-03-10T04:45:30',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 80}
#
#
# {'confidence': 81,
#  'datetime': '2018-03-10T04:43:50',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 55}
#
#
# {'confidence': 86,
#  'datetime': '2018-03-09T13:23:40',
#  'from_climate_historic': [{'air_temperature_celcius': 23}],
#  'surface_temperature_celcius': 41}
#
#
# {'confidence': 88,
#  'datetime': '2018-03-07T04:16:10',
#  'from_climate_historic': [{'air_temperature_celcius': 19}],
#  'surface_temperature_celcius': 64}
#
#
# {'confidence': 87,
#  'datetime': '2018-03-06T05:06:30',
#  'from_climate_historic': [{'air_temperature_celcius': 20}],
#  'surface_temperature_celcius': 62}
#
#
# {'confidence': 85,
#  'datetime': '2018-03-06T05:06:20',
#  'from_climate_historic': [{'air_temperature_celcius': 20}],
#  'surface_temperature_celcius': 59}

# %%
# e. Find the top 10 records with the highest surface temperature (°C).

cursor = db.hotspot.aggregate([
    {"$lookup" : {
        "from" : "climate",
        "localField": "foreign_key",
        "foreignField": "_id",
        "as": "from_climate_historic"
        }},
    {"$sort" : {"surface_temperature_celcius":-1}},
    {"$limit" : 10 }
    ])

cursor = db.hotspot.find({}).sort("surface_temperature_celcius", -1).limit(10)

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'_id': ObjectId('60a3c91a1b38980f0d0c6dbc'),
#  'confidence': 100,
#  'date': '2018-04-18',
#  'datetime': '2018-04-18T04:52:00',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6816'),
#  'latitude': -38.1665,
#  'longitude': 143.062,
#  'surface_temperature_celcius': 124}
#
#
# {'_id': ObjectId('60a3c91b1b38980f0d0c7266'),
#  'confidence': 100,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:50',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6808'),
#  'latitude': -36.343,
#  'longitude': 142.1986,
#  'surface_temperature_celcius': 123}
#
#
# {'_id': ObjectId('60a3c91a1b38980f0d0c6d2e'),
#  'confidence': 100,
#  'date': '2018-05-01',
#  'datetime': '2018-05-01T04:14:20',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6823'),
#  'latitude': -36.9318,
#  'longitude': 143.0907,
#  'surface_temperature_celcius': 122}
#
#
# {'_id': ObjectId('60a3c91b1b38980f0d0c7355'),
#  'confidence': 100,
#  'date': '2018-03-18',
#  'datetime': '2018-03-18T03:50:50',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c67f7'),
#  'latitude': -37.017,
#  'longitude': 148.1297,
#  'surface_temperature_celcius': 121}
#
#
# {'_id': ObjectId('60a3c91a1b38980f0d0c6b40'),
#  'confidence': 100,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:40:20',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c682f'),
#  'latitude': -34.9938,
#  'longitude': 141.876,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': ObjectId('60a3c91b1b38980f0d0c722d'),
#  'confidence': 100,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:40:00',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6808'),
#  'latitude': -36.1057,
#  'longitude': 141.7608,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': ObjectId('60a3c91b1b38980f0d0c726d'),
#  'confidence': 100,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6808'),
#  'latitude': -36.3521,
#  'longitude': 142.2008,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': ObjectId('60a3c91b1b38980f0d0c6fd8'),
#  'confidence': 100,
#  'date': '2018-04-13',
#  'datetime': '2018-04-13T04:28:10',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6811'),
#  'latitude': -37.0745,
#  'longitude': 141.0692,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': ObjectId('60a3c91a1b38980f0d0c6e55'),
#  'confidence': 100,
#  'date': '2018-04-18',
#  'datetime': '2018-04-18T04:44:50',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6816'),
#  'latitude': -37.8326,
#  'longitude': 143.4999,
#  'surface_temperature_celcius': 120}
#
#
# {'_id': ObjectId('60a3c91a1b38980f0d0c6c84'),
#  'confidence': 100,
#  'date': '2018-05-04',
#  'datetime': '2018-05-04T04:44:50',
#  'foreign_key': ObjectId('60a3c9191b38980f0d0c6826'),
#  'latitude': -36.4057,
#  'longitude': 140.9806,
#  'surface_temperature_celcius': 119}

# %%
# f. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

cursor = db.climate.aggregate([
    {"$lookup" : {
        "from" : "hotspot",
        "localField": "_id",
        "foreignField": "foreign_key",
        "as": "from_hotspot_historic"
        }},
    {"$addFields" : {
        "total_number_of_fires" : {"$size": "$from_hotspot_historic"}
        }},
    {"$project" : {
        '_id':0,
        'date':1,
        'total_number_of_fires':1
    }},
    {"$sort": {"date":1}}
])

for i in cursor:
    pprint(i)
# Out:
# {'date': '2017-12-31', 'total_number_of_fires': 0}
# {'date': '2018-01-01', 'total_number_of_fires': 0}
# {'date': '2018-01-02', 'total_number_of_fires': 0}
# {'date': '2018-01-03', 'total_number_of_fires': 0}
# {'date': '2018-01-04', 'total_number_of_fires': 0}
# {'date': '2018-01-05', 'total_number_of_fires': 0}
# {'date': '2018-01-06', 'total_number_of_fires': 0}
# {'date': '2018-01-07', 'total_number_of_fires': 0}
# {'date': '2018-01-08', 'total_number_of_fires': 0}
# {'date': '2018-01-09', 'total_number_of_fires': 0}
# {'date': '2018-01-10', 'total_number_of_fires': 0}
# {'date': '2018-01-11', 'total_number_of_fires': 0}
# {'date': '2018-01-12', 'total_number_of_fires': 0}
# {'date': '2018-01-13', 'total_number_of_fires': 0}
# {'date': '2018-01-14', 'total_number_of_fires': 0}
# {'date': '2018-01-15', 'total_number_of_fires': 0}
# {'date': '2018-01-16', 'total_number_of_fires': 0}
# {'date': '2018-01-17', 'total_number_of_fires': 0}
# {'date': '2018-01-18', 'total_number_of_fires': 0}
# {'date': '2018-01-19', 'total_number_of_fires': 0}
# {'date': '2018-01-20', 'total_number_of_fires': 0}
# {'date': '2018-01-21', 'total_number_of_fires': 0}
# {'date': '2018-01-22', 'total_number_of_fires': 0}
# {'date': '2018-01-23', 'total_number_of_fires': 0}
# {'date': '2018-01-24', 'total_number_of_fires': 0}
# {'date': '2018-01-25', 'total_number_of_fires': 0}
# {'date': '2018-01-26', 'total_number_of_fires': 0}
# {'date': '2018-01-27', 'total_number_of_fires': 0}
# {'date': '2018-01-28', 'total_number_of_fires': 0}
# {'date': '2018-01-29', 'total_number_of_fires': 0}
# {'date': '2018-01-30', 'total_number_of_fires': 0}
# {'date': '2018-01-31', 'total_number_of_fires': 0}
# {'date': '2018-02-01', 'total_number_of_fires': 0}
# {'date': '2018-02-02', 'total_number_of_fires': 0}
# {'date': '2018-02-03', 'total_number_of_fires': 0}
# {'date': '2018-02-04', 'total_number_of_fires': 0}
# {'date': '2018-02-05', 'total_number_of_fires': 0}
# {'date': '2018-02-06', 'total_number_of_fires': 0}
# {'date': '2018-02-07', 'total_number_of_fires': 0}
# {'date': '2018-02-08', 'total_number_of_fires': 0}
# {'date': '2018-02-09', 'total_number_of_fires': 0}
# {'date': '2018-02-10', 'total_number_of_fires': 0}
# {'date': '2018-02-11', 'total_number_of_fires': 0}
# {'date': '2018-02-12', 'total_number_of_fires': 0}
# {'date': '2018-02-13', 'total_number_of_fires': 0}
# {'date': '2018-02-14', 'total_number_of_fires': 0}
# {'date': '2018-02-15', 'total_number_of_fires': 0}
# {'date': '2018-02-16', 'total_number_of_fires': 0}
# {'date': '2018-02-17', 'total_number_of_fires': 0}
# {'date': '2018-02-18', 'total_number_of_fires': 0}
# {'date': '2018-02-19', 'total_number_of_fires': 0}
# {'date': '2018-02-20', 'total_number_of_fires': 0}
# {'date': '2018-02-21', 'total_number_of_fires': 0}
# {'date': '2018-02-22', 'total_number_of_fires': 0}
# {'date': '2018-02-23', 'total_number_of_fires': 0}
# {'date': '2018-02-24', 'total_number_of_fires': 0}
# {'date': '2018-02-25', 'total_number_of_fires': 0}
# {'date': '2018-02-26', 'total_number_of_fires': 0}
# {'date': '2018-02-27', 'total_number_of_fires': 0}
# {'date': '2018-02-28', 'total_number_of_fires': 0}
# {'date': '2018-03-01', 'total_number_of_fires': 0}
# {'date': '2018-03-02', 'total_number_of_fires': 0}
# {'date': '2018-03-03', 'total_number_of_fires': 0}
# {'date': '2018-03-04', 'total_number_of_fires': 0}
# {'date': '2018-03-05', 'total_number_of_fires': 0}
# {'date': '2018-03-06', 'total_number_of_fires': 2}
# {'date': '2018-03-07', 'total_number_of_fires': 1}
# {'date': '2018-03-08', 'total_number_of_fires': 2}
# {'date': '2018-03-09', 'total_number_of_fires': 3}
# {'date': '2018-03-10', 'total_number_of_fires': 8}
# {'date': '2018-03-11', 'total_number_of_fires': 0}
# {'date': '2018-03-12', 'total_number_of_fires': 5}
# {'date': '2018-03-13', 'total_number_of_fires': 2}
# {'date': '2018-03-14', 'total_number_of_fires': 10}
# {'date': '2018-03-15', 'total_number_of_fires': 7}
# {'date': '2018-03-16', 'total_number_of_fires': 0}
# {'date': '2018-03-17', 'total_number_of_fires': 6}
# {'date': '2018-03-18', 'total_number_of_fires': 3}
# {'date': '2018-03-19', 'total_number_of_fires': 21}
# {'date': '2018-03-20', 'total_number_of_fires': 0}
# {'date': '2018-03-21', 'total_number_of_fires': 0}
# {'date': '2018-03-22', 'total_number_of_fires': 0}
# {'date': '2018-03-23', 'total_number_of_fires': 0}
# {'date': '2018-03-24', 'total_number_of_fires': 2}
# {'date': '2018-03-25', 'total_number_of_fires': 13}
# {'date': '2018-03-26', 'total_number_of_fires': 17}
# {'date': '2018-03-27', 'total_number_of_fires': 0}
# {'date': '2018-03-28', 'total_number_of_fires': 54}
# {'date': '2018-03-29', 'total_number_of_fires': 1}
# {'date': '2018-03-30', 'total_number_of_fires': 0}
# {'date': '2018-03-31', 'total_number_of_fires': 22}
# {'date': '2018-04-01', 'total_number_of_fires': 7}
# {'date': '2018-04-02', 'total_number_of_fires': 5}
# {'date': '2018-04-03', 'total_number_of_fires': 72}
# {'date': '2018-04-04', 'total_number_of_fires': 89}
# {'date': '2018-04-05', 'total_number_of_fires': 49}
# {'date': '2018-04-06', 'total_number_of_fires': 118}
# {'date': '2018-04-07', 'total_number_of_fires': 39}
# {'date': '2018-04-08', 'total_number_of_fires': 20}
# {'date': '2018-04-09', 'total_number_of_fires': 0}
# {'date': '2018-04-10', 'total_number_of_fires': 0}
# {'date': '2018-04-11', 'total_number_of_fires': 24}
# {'date': '2018-04-12', 'total_number_of_fires': 69}
# {'date': '2018-04-13', 'total_number_of_fires': 357}
# {'date': '2018-04-14', 'total_number_of_fires': 18}
# {'date': '2018-04-15', 'total_number_of_fires': 69}
# {'date': '2018-04-16', 'total_number_of_fires': 18}
# {'date': '2018-04-17', 'total_number_of_fires': 38}
# {'date': '2018-04-18', 'total_number_of_fires': 325}
# {'date': '2018-04-19', 'total_number_of_fires': 50}
# {'date': '2018-04-20', 'total_number_of_fires': 31}
# {'date': '2018-04-21', 'total_number_of_fires': 0}
# {'date': '2018-04-22', 'total_number_of_fires': 2}
# {'date': '2018-04-23', 'total_number_of_fires': 19}
# {'date': '2018-04-24', 'total_number_of_fires': 8}
# {'date': '2018-04-25', 'total_number_of_fires': 3}
# {'date': '2018-04-26', 'total_number_of_fires': 1}
# {'date': '2018-04-27', 'total_number_of_fires': 0}
# {'date': '2018-04-28', 'total_number_of_fires': 0}
# {'date': '2018-04-29', 'total_number_of_fires': 3}
# {'date': '2018-04-30', 'total_number_of_fires': 0}
# {'date': '2018-05-01', 'total_number_of_fires': 20}
# {'date': '2018-05-02', 'total_number_of_fires': 10}
# {'date': '2018-05-03', 'total_number_of_fires': 64}
# {'date': '2018-05-04', 'total_number_of_fires': 135}
# {'date': '2018-05-05', 'total_number_of_fires': 31}
# {'date': '2018-05-06', 'total_number_of_fires': 17}
# {'date': '2018-05-07', 'total_number_of_fires': 3}
# {'date': '2018-05-08', 'total_number_of_fires': 24}
# {'date': '2018-05-09', 'total_number_of_fires': 13}
# {'date': '2018-05-10', 'total_number_of_fires': 114}
# {'date': '2018-05-11', 'total_number_of_fires': 19}
# {'date': '2018-05-12', 'total_number_of_fires': 10}
# {'date': '2018-05-13', 'total_number_of_fires': 54}
# {'date': '2018-05-14', 'total_number_of_fires': 1}
# {'date': '2018-05-15', 'total_number_of_fires': 102}
# {'date': '2018-05-16', 'total_number_of_fires': 3}
# {'date': '2018-05-17', 'total_number_of_fires': 1}
# {'date': '2018-05-18', 'total_number_of_fires': 7}
# {'date': '2018-05-19', 'total_number_of_fires': 0}
# {'date': '2018-05-20', 'total_number_of_fires': 0}
# {'date': '2018-05-21', 'total_number_of_fires': 0}
# {'date': '2018-05-22', 'total_number_of_fires': 33}
# {'date': '2018-05-23', 'total_number_of_fires': 5}
# {'date': '2018-05-24', 'total_number_of_fires': 3}
# {'date': '2018-05-25', 'total_number_of_fires': 0}
# {'date': '2018-05-26', 'total_number_of_fires': 4}
# {'date': '2018-05-27', 'total_number_of_fires': 0}
# {'date': '2018-05-28', 'total_number_of_fires': 0}
# {'date': '2018-05-29', 'total_number_of_fires': 0}
# {'date': '2018-05-30', 'total_number_of_fires': 0}
# {'date': '2018-05-31', 'total_number_of_fires': 0}
# {'date': '2018-06-01', 'total_number_of_fires': 2}
# {'date': '2018-06-02', 'total_number_of_fires': 11}
# {'date': '2018-06-03', 'total_number_of_fires': 2}
# {'date': '2018-06-04', 'total_number_of_fires': 9}
# {'date': '2018-06-05', 'total_number_of_fires': 0}
# {'date': '2018-06-06', 'total_number_of_fires': 0}
# {'date': '2018-06-07', 'total_number_of_fires': 14}
# {'date': '2018-06-08', 'total_number_of_fires': 0}
# {'date': '2018-06-09', 'total_number_of_fires': 3}
# {'date': '2018-06-10', 'total_number_of_fires': 0}
# {'date': '2018-06-11', 'total_number_of_fires': 2}
# {'date': '2018-06-12', 'total_number_of_fires': 0}
# {'date': '2018-06-13', 'total_number_of_fires': 1}
# {'date': '2018-06-14', 'total_number_of_fires': 4}
# {'date': '2018-06-15', 'total_number_of_fires': 0}
# {'date': '2018-06-16', 'total_number_of_fires': 2}
# {'date': '2018-06-17', 'total_number_of_fires': 0}
# {'date': '2018-06-18', 'total_number_of_fires': 2}
# {'date': '2018-06-19', 'total_number_of_fires': 0}
# {'date': '2018-06-20', 'total_number_of_fires': 6}
# {'date': '2018-06-21', 'total_number_of_fires': 0}
# {'date': '2018-06-22', 'total_number_of_fires': 1}
# {'date': '2018-06-23', 'total_number_of_fires': 0}
# {'date': '2018-06-24', 'total_number_of_fires': 0}
# {'date': '2018-06-25', 'total_number_of_fires': 0}
# {'date': '2018-06-26', 'total_number_of_fires': 0}
# {'date': '2018-06-27', 'total_number_of_fires': 0}
# {'date': '2018-06-28', 'total_number_of_fires': 0}
# {'date': '2018-06-29', 'total_number_of_fires': 0}
# {'date': '2018-06-30', 'total_number_of_fires': 6}
# {'date': '2018-07-01', 'total_number_of_fires': 4}
# {'date': '2018-07-02', 'total_number_of_fires': 8}
# {'date': '2018-07-03', 'total_number_of_fires': 0}
# {'date': '2018-07-04', 'total_number_of_fires': 1}
# {'date': '2018-07-05', 'total_number_of_fires': 1}
# {'date': '2018-07-06', 'total_number_of_fires': 3}
# {'date': '2018-07-07', 'total_number_of_fires': 0}
# {'date': '2018-07-08', 'total_number_of_fires': 0}
# {'date': '2018-07-09', 'total_number_of_fires': 0}
# {'date': '2018-07-10', 'total_number_of_fires': 0}
# {'date': '2018-07-11', 'total_number_of_fires': 0}
# {'date': '2018-07-12', 'total_number_of_fires': 0}
# {'date': '2018-07-13', 'total_number_of_fires': 0}
# {'date': '2018-07-14', 'total_number_of_fires': 2}
# {'date': '2018-07-15', 'total_number_of_fires': 0}
# {'date': '2018-07-16', 'total_number_of_fires': 0}
# {'date': '2018-07-17', 'total_number_of_fires': 0}
# {'date': '2018-07-18', 'total_number_of_fires': 0}
# {'date': '2018-07-19', 'total_number_of_fires': 0}
# {'date': '2018-07-20', 'total_number_of_fires': 0}
# {'date': '2018-07-21', 'total_number_of_fires': 0}
# {'date': '2018-07-22', 'total_number_of_fires': 0}
# {'date': '2018-07-23', 'total_number_of_fires': 0}
# {'date': '2018-07-24', 'total_number_of_fires': 0}
# {'date': '2018-07-25', 'total_number_of_fires': 0}
# {'date': '2018-07-26', 'total_number_of_fires': 0}
# {'date': '2018-07-27', 'total_number_of_fires': 0}
# {'date': '2018-07-28', 'total_number_of_fires': 0}
# {'date': '2018-07-29', 'total_number_of_fires': 2}
# {'date': '2018-07-30', 'total_number_of_fires': 0}
# {'date': '2018-07-31', 'total_number_of_fires': 2}
# {'date': '2018-08-01', 'total_number_of_fires': 2}
# {'date': '2018-08-02', 'total_number_of_fires': 2}
# {'date': '2018-08-03', 'total_number_of_fires': 0}
# {'date': '2018-08-04', 'total_number_of_fires': 0}
# {'date': '2018-08-05', 'total_number_of_fires': 1}
# {'date': '2018-08-06', 'total_number_of_fires': 0}
# {'date': '2018-08-07', 'total_number_of_fires': 0}
# {'date': '2018-08-08', 'total_number_of_fires': 0}
# {'date': '2018-08-09', 'total_number_of_fires': 0}
# {'date': '2018-08-10', 'total_number_of_fires': 1}
# {'date': '2018-08-11', 'total_number_of_fires': 0}
# {'date': '2018-08-12', 'total_number_of_fires': 0}
# {'date': '2018-08-13', 'total_number_of_fires': 9}
# {'date': '2018-08-14', 'total_number_of_fires': 5}
# {'date': '2018-08-15', 'total_number_of_fires': 0}
# {'date': '2018-08-16', 'total_number_of_fires': 0}
# {'date': '2018-08-17', 'total_number_of_fires': 0}
# {'date': '2018-08-18', 'total_number_of_fires': 0}
# {'date': '2018-08-19', 'total_number_of_fires': 0}
# {'date': '2018-08-20', 'total_number_of_fires': 0}
# {'date': '2018-08-21', 'total_number_of_fires': 0}
# {'date': '2018-08-22', 'total_number_of_fires': 0}
# {'date': '2018-08-23', 'total_number_of_fires': 0}
# {'date': '2018-08-24', 'total_number_of_fires': 0}
# {'date': '2018-08-25', 'total_number_of_fires': 0}
# {'date': '2018-08-26', 'total_number_of_fires': 0}
# {'date': '2018-08-27', 'total_number_of_fires': 0}
# {'date': '2018-08-28', 'total_number_of_fires': 0}
# {'date': '2018-08-29', 'total_number_of_fires': 0}
# {'date': '2018-08-30', 'total_number_of_fires': 0}
# {'date': '2018-08-31', 'total_number_of_fires': 0}
# {'date': '2018-09-01', 'total_number_of_fires': 0}
# {'date': '2018-09-02', 'total_number_of_fires': 0}
# {'date': '2018-09-03', 'total_number_of_fires': 0}
# {'date': '2018-09-04', 'total_number_of_fires': 0}
# {'date': '2018-09-05', 'total_number_of_fires': 0}
# {'date': '2018-09-06', 'total_number_of_fires': 0}
# {'date': '2018-09-07', 'total_number_of_fires': 0}
# {'date': '2018-09-08', 'total_number_of_fires': 0}
# {'date': '2018-09-09', 'total_number_of_fires': 0}
# {'date': '2018-09-10', 'total_number_of_fires': 4}
# {'date': '2018-09-11', 'total_number_of_fires': 0}
# {'date': '2018-09-12', 'total_number_of_fires': 0}
# {'date': '2018-09-13', 'total_number_of_fires': 0}
# {'date': '2018-09-14', 'total_number_of_fires': 0}
# {'date': '2018-09-15', 'total_number_of_fires': 0}
# {'date': '2018-09-16', 'total_number_of_fires': 0}
# {'date': '2018-09-17', 'total_number_of_fires': 0}
# {'date': '2018-09-18', 'total_number_of_fires': 0}
# {'date': '2018-09-19', 'total_number_of_fires': 0}
# {'date': '2018-09-20', 'total_number_of_fires': 5}
# {'date': '2018-09-21', 'total_number_of_fires': 2}
# {'date': '2018-09-22', 'total_number_of_fires': 1}
# {'date': '2018-09-23', 'total_number_of_fires': 23}
# {'date': '2018-09-24', 'total_number_of_fires': 28}
# {'date': '2018-09-25', 'total_number_of_fires': 0}
# {'date': '2018-09-26', 'total_number_of_fires': 1}
# {'date': '2018-09-27', 'total_number_of_fires': 7}
# {'date': '2018-09-28', 'total_number_of_fires': 0}
# {'date': '2018-09-29', 'total_number_of_fires': 2}
# {'date': '2018-09-30', 'total_number_of_fires': 0}
# {'date': '2018-10-01', 'total_number_of_fires': 8}
# {'date': '2018-10-02', 'total_number_of_fires': 7}
# {'date': '2018-10-03', 'total_number_of_fires': 18}
# {'date': '2018-10-04', 'total_number_of_fires': 5}
# {'date': '2018-10-05', 'total_number_of_fires': 0}
# {'date': '2018-10-06', 'total_number_of_fires': 2}
# {'date': '2018-10-07', 'total_number_of_fires': 1}
# {'date': '2018-10-08', 'total_number_of_fires': 1}
# {'date': '2018-10-09', 'total_number_of_fires': 1}
# {'date': '2018-10-10', 'total_number_of_fires': 3}
# {'date': '2018-10-11', 'total_number_of_fires': 0}
# {'date': '2018-10-12', 'total_number_of_fires': 0}
# {'date': '2018-10-13', 'total_number_of_fires': 0}
# {'date': '2018-10-14', 'total_number_of_fires': 0}
# {'date': '2018-10-15', 'total_number_of_fires': 3}
# {'date': '2018-10-16', 'total_number_of_fires': 1}
# {'date': '2018-10-17', 'total_number_of_fires': 5}
# {'date': '2018-10-18', 'total_number_of_fires': 6}
# {'date': '2018-10-19', 'total_number_of_fires': 0}
# {'date': '2018-10-20', 'total_number_of_fires': 3}
# {'date': '2018-10-21', 'total_number_of_fires': 4}
# {'date': '2018-10-22', 'total_number_of_fires': 0}
# {'date': '2018-10-23', 'total_number_of_fires': 1}
# {'date': '2018-10-24', 'total_number_of_fires': 0}
# {'date': '2018-10-25', 'total_number_of_fires': 0}
# {'date': '2018-10-26', 'total_number_of_fires': 5}
# {'date': '2018-10-27', 'total_number_of_fires': 5}
# {'date': '2018-10-28', 'total_number_of_fires': 1}
# {'date': '2018-10-29', 'total_number_of_fires': 0}
# {'date': '2018-10-30', 'total_number_of_fires': 0}
# {'date': '2018-10-31', 'total_number_of_fires': 0}
# {'date': '2018-11-01', 'total_number_of_fires': 0}
# {'date': '2018-11-02', 'total_number_of_fires': 0}
# {'date': '2018-11-03', 'total_number_of_fires': 0}
# {'date': '2018-11-04', 'total_number_of_fires': 0}
# {'date': '2018-11-05', 'total_number_of_fires': 4}
# {'date': '2018-11-06', 'total_number_of_fires': 0}
# {'date': '2018-11-07', 'total_number_of_fires': 0}
# {'date': '2018-11-08', 'total_number_of_fires': 2}
# {'date': '2018-11-09', 'total_number_of_fires': 10}
# {'date': '2018-11-10', 'total_number_of_fires': 0}
# {'date': '2018-11-11', 'total_number_of_fires': 4}
# {'date': '2018-11-12', 'total_number_of_fires': 5}
# {'date': '2018-11-13', 'total_number_of_fires': 5}
# {'date': '2018-11-14', 'total_number_of_fires': 3}
# {'date': '2018-11-15', 'total_number_of_fires': 0}
# {'date': '2018-11-16', 'total_number_of_fires': 0}
# {'date': '2018-11-17', 'total_number_of_fires': 0}
# {'date': '2018-11-18', 'total_number_of_fires': 0}
# {'date': '2018-11-19', 'total_number_of_fires': 0}
# {'date': '2018-11-20', 'total_number_of_fires': 0}
# {'date': '2018-11-21', 'total_number_of_fires': 1}
# {'date': '2018-11-22', 'total_number_of_fires': 2}
# {'date': '2018-11-23', 'total_number_of_fires': 5}
# {'date': '2018-11-24', 'total_number_of_fires': 0}
# {'date': '2018-11-25', 'total_number_of_fires': 0}
# {'date': '2018-11-26', 'total_number_of_fires': 0}
# {'date': '2018-11-27', 'total_number_of_fires': 0}
# {'date': '2018-11-28', 'total_number_of_fires': 1}
# {'date': '2018-11-29', 'total_number_of_fires': 8}
# {'date': '2018-11-30', 'total_number_of_fires': 31}
# {'date': '2018-12-01', 'total_number_of_fires': 0}
# {'date': '2018-12-02', 'total_number_of_fires': 0}
# {'date': '2018-12-03', 'total_number_of_fires': 0}
# {'date': '2018-12-04', 'total_number_of_fires': 0}
# {'date': '2018-12-05', 'total_number_of_fires': 0}
# {'date': '2018-12-06', 'total_number_of_fires': 0}
# {'date': '2018-12-07', 'total_number_of_fires': 0}
# {'date': '2018-12-08', 'total_number_of_fires': 5}
# {'date': '2018-12-09', 'total_number_of_fires': 4}
# {'date': '2018-12-10', 'total_number_of_fires': 2}
# {'date': '2018-12-11', 'total_number_of_fires': 0}
# {'date': '2018-12-12', 'total_number_of_fires': 1}
# {'date': '2018-12-13', 'total_number_of_fires': 1}
# {'date': '2018-12-14', 'total_number_of_fires': 1}
# {'date': '2018-12-15', 'total_number_of_fires': 4}
# {'date': '2018-12-16', 'total_number_of_fires': 15}
# {'date': '2018-12-17', 'total_number_of_fires': 0}
# {'date': '2018-12-18', 'total_number_of_fires': 0}
# {'date': '2018-12-19', 'total_number_of_fires': 0}
# {'date': '2018-12-20', 'total_number_of_fires': 0}
# {'date': '2018-12-21', 'total_number_of_fires': 1}
# {'date': '2018-12-22', 'total_number_of_fires': 0}
# {'date': '2018-12-23', 'total_number_of_fires': 0}
# {'date': '2018-12-24', 'total_number_of_fires': 1}
# {'date': '2018-12-25', 'total_number_of_fires': 1}
# {'date': '2018-12-26', 'total_number_of_fires': 0}
# {'date': '2018-12-27', 'total_number_of_fires': 4}
# {'date': '2018-12-28', 'total_number_of_fires': 0}
# {'date': '2018-12-29', 'total_number_of_fires': 0}
# {'date': '2018-12-30', 'total_number_of_fires': 0}
# {'date': '2018-12-31', 'total_number_of_fires': 0}

# %%
# g. Find the records of fires where the confidence is below 70.

cursor = db.hotspot.aggregate([
    {"$lookup" : {
        "from" : "climate",
        "localField": "foreign_key",
        "foreignField": "_id",
        "as": "from_climate_historic"
        }},
    {"$match" : {
        'confidence' : {"$lt":70}
        }}
    ])

cursor = db.hotspot.find({'confidence' : {"$lt":70}})

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'_id': ObjectId('60a352919343695b37c4ddbf'),
#  'confidence': 67,
#  'date': '2018-12-27',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddc2'),
#  'confidence': 65,
#  'date': '2018-12-24',
#  'datetime': '2018-12-24T13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddc5'),
#  'confidence': 69,
#  'date': '2018-12-16',
#  'datetime': '2018-12-16T15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddc6'),
#  'confidence': 62,
#  'date': '2018-12-16',
#  'datetime': '2018-12-16T04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddca'),
#  'confidence': 59,
#  'date': '2018-12-16',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddcf'),
#  'confidence': 60,
#  'date': '2018-12-16',
#  'datetime': '2018-12-16T00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddd2'),
#  'confidence': 53,
#  'date': '2018-12-16',
#  'datetime': '2018-12-16T00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddd5'),
#  'confidence': 51,
#  'date': '2018-12-15',
#  'datetime': '2018-12-15T13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddd6'),
#  'confidence': 65,
#  'date': '2018-12-15',
#  'datetime': '2018-12-15T01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddd9'),
#  'confidence': 53,
#  'date': '2018-12-12',
#  'datetime': '2018-12-12T00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddda'),
#  'confidence': 50,
#  'date': '2018-12-10',
#  'datetime': '2018-12-10T00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4dddb'),
#  'confidence': 67,
#  'date': '2018-12-10',
#  'datetime': '2018-12-10T00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352919343695b37c4dde4'),
#  'confidence': 56,
#  'date': '2018-12-08',
#  'datetime': '2018-12-08T13:11:43',
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4dde5'),
#  'confidence': 52,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
#
#
# {'_id': ObjectId('60a352919343695b37c4dde7'),
#  'confidence': 51,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dde8'),
#  'confidence': 64,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddea'),
#  'confidence': 69,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddec'),
#  'confidence': 61,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
#
#
# {'_id': ObjectId('60a352919343695b37c4dded'),
#  'confidence': 62,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddee'),
#  'confidence': 64,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddfa'),
#  'confidence': 69,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352919343695b37c4ddfb'),
#  'confidence': 60,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4de02'),
#  'confidence': 69,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352919343695b37c4de03'),
#  'confidence': 64,
#  'date': '2018-11-30',
#  'datetime': '2018-11-30T00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de04'),
#  'confidence': 53,
#  'date': '2018-11-29',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4de06'),
#  'confidence': 68,
#  'date': '2018-11-29',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4de07'),
#  'confidence': 52,
#  'date': '2018-11-29',
#  'datetime': '2018-11-29T03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352919343695b37c4de09'),
#  'confidence': 64,
#  'date': '2018-11-29',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4de0c'),
#  'confidence': 50,
#  'date': '2018-11-28',
#  'datetime': '2018-11-28T00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4de0f'),
#  'confidence': 68,
#  'date': '2018-11-23',
#  'datetime': '2018-11-23T00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352919343695b37c4de10'),
#  'confidence': 63,
#  'date': '2018-11-23',
#  'datetime': '2018-11-23T00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
#
#
# {'_id': ObjectId('60a352919343695b37c4de16'),
#  'confidence': 64,
#  'date': '2018-11-14',
#  'datetime': '2018-11-14T00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4de17'),
#  'confidence': 64,
#  'date': '2018-11-14',
#  'datetime': '2018-11-14T00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1a'),
#  'confidence': 64,
#  'date': '2018-11-13',
#  'datetime': '2018-11-13T03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1b'),
#  'confidence': 51,
#  'date': '2018-11-13',
#  'datetime': '2018-11-13T01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1c'),
#  'confidence': 62,
#  'date': '2018-11-13',
#  'datetime': '2018-11-13T01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1d'),
#  'confidence': 63,
#  'date': '2018-11-12',
#  'datetime': '2018-11-12T04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1e'),
#  'confidence': 58,
#  'date': '2018-11-12',
#  'datetime': '2018-11-12T04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de1f'),
#  'confidence': 56,
#  'date': '2018-11-12',
#  'datetime': '2018-11-12T04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352919343695b37c4de20'),
#  'confidence': 67,
#  'date': '2018-11-12',
#  'datetime': '2018-11-12T00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352919343695b37c4de22'),
#  'confidence': 51,
#  'date': '2018-11-11',
#  'datetime': '2018-11-11T15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
#
#
# {'_id': ObjectId('60a352919343695b37c4de26'),
#  'confidence': 68,
#  'date': '2018-11-09',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
#
#
# {'_id': ObjectId('60a352919343695b37c4de27'),
#  'confidence': 62,
#  'date': '2018-11-09',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
#
#
# {'_id': ObjectId('60a352919343695b37c4de2d'),
#  'confidence': 63,
#  'date': '2018-11-09',
#  'datetime': '2018-11-09T04:16:46',
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de30'),
#  'confidence': 60,
#  'date': '2018-11-08',
#  'datetime': '2018-11-08T05:12:08',
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4de37'),
#  'confidence': 62,
#  'date': '2018-10-27',
#  'datetime': '2018-10-27T04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4de3f'),
#  'confidence': 67,
#  'date': '2018-10-26',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4de40'),
#  'confidence': 69,
#  'date': '2018-10-26',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4de44'),
#  'confidence': 65,
#  'date': '2018-10-21',
#  'datetime': '2018-10-21T01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352919343695b37c4de48'),
#  'confidence': 65,
#  'date': '2018-10-20',
#  'datetime': '2018-10-20T00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352919343695b37c4de52'),
#  'confidence': 58,
#  'date': '2018-10-17',
#  'datetime': '2018-10-17T04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de54'),
#  'confidence': 62,
#  'date': '2018-10-16',
#  'datetime': '2018-10-16T23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
#
#
# {'_id': ObjectId('60a352919343695b37c4de60'),
#  'confidence': 50,
#  'date': '2018-10-04',
#  'datetime': '2018-10-04T04:41:36',
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4de65'),
#  'confidence': 69,
#  'date': '2018-10-03',
#  'datetime': '2018-10-03T15:01:44',
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
#
#
# {'_id': ObjectId('60a352919343695b37c4de67'),
#  'confidence': 68,
#  'date': '2018-10-03',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.236,
#  'longitude': 141.176,
#  'surface_temperature_celcius': 37}
#
#
# {'_id': ObjectId('60a352919343695b37c4de68'),
#  'confidence': 59,
#  'date': '2018-10-03',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352919343695b37c4de76'),
#  'confidence': 54,
#  'date': '2018-10-03',
#  'datetime': '2018-10-03T01:22:44',
#  'latitude': -37.227,
#  'longitude': 141.146,
#  'surface_temperature_celcius': 31}
#
#
# {'_id': ObjectId('60a352919343695b37c4de77'),
#  'confidence': 50,
#  'date': '2018-10-02',
#  'datetime': '2018-10-02T23:44:31',
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
#
#
# {'_id': ObjectId('60a352919343695b37c4de78'),
#  'confidence': 59,
#  'date': '2018-10-02',
#  'datetime': '2018-10-02T04:53:10',
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4de7d'),
#  'confidence': 68,
#  'date': '2018-10-02',
#  'datetime': '2018-10-02T00:39:34',
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4de7e'),
#  'confidence': 62,
#  'date': '2018-10-01',
#  'datetime': '2018-10-01T15:13:56',
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
#
#
# {'_id': ObjectId('60a352919343695b37c4de84'),
#  'confidence': 64,
#  'date': '2018-10-01',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
#
#
# {'_id': ObjectId('60a352919343695b37c4de8c'),
#  'confidence': 65,
#  'date': '2018-09-27',
#  'datetime': '2018-09-27T04:35:18',
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4de8f'),
#  'confidence': 64,
#  'date': '2018-09-26',
#  'datetime': '2018-09-26T03:52:14',
#  'latitude': -37.087,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
#
#
# {'_id': ObjectId('60a352919343695b37c4de9c'),
#  'confidence': 59,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352919343695b37c4dea2'),
#  'confidence': 58,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:19',
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
#
#
# {'_id': ObjectId('60a352919343695b37c4dea3'),
#  'confidence': 68,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
#
#
# {'_id': ObjectId('60a352919343695b37c4dea4'),
#  'confidence': 68,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
#
#
# {'_id': ObjectId('60a352919343695b37c4dea5'),
#  'confidence': 64,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
#
#
# {'_id': ObjectId('60a352919343695b37c4dea8'),
#  'confidence': 61,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:17',
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
#
#
# {'_id': ObjectId('60a352919343695b37c4deab'),
#  'confidence': 56,
#  'date': '2018-09-24',
#  'datetime': '2018-09-24T04:04:04',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'surface_temperature_celcius': 53}
#
#
# {'_id': ObjectId('60a352919343695b37c4deae'),
#  'confidence': 56,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T23:50:43',
#  'latitude': -37.559,
#  'longitude': 148.037,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4deaf'),
#  'confidence': 58,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
#
#
# {'_id': ObjectId('60a352919343695b37c4deb0'),
#  'confidence': 62,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
#
#
# {'_id': ObjectId('60a352919343695b37c4deb9'),
#  'confidence': 50,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T04:59:18',
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352919343695b37c4debb'),
#  'confidence': 61,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T04:59:13',
#  'latitude': -37.347,
#  'longitude': 148.019,
#  'surface_temperature_celcius': 36}
#
#
# {'_id': ObjectId('60a352919343695b37c4dec0'),
#  'confidence': 56,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T03:21:28',
#  'latitude': -36.995,
#  'longitude': 148.268,
#  'surface_temperature_celcius': 37}
#
#
# {'_id': ObjectId('60a352919343695b37c4dec1'),
#  'confidence': 63,
#  'date': '2018-09-23',
#  'datetime': '2018-09-23T03:21:19',
#  'latitude': -37.554,
#  'longitude': 148.073,
#  'surface_temperature_celcius': 37}
#
#
# {'_id': ObjectId('60a352919343695b37c4decf'),
#  'confidence': 56,
#  'date': '2018-08-14',
#  'datetime': '2018-08-14T04:15:40',
#  'latitude': -37.4421,
#  'longitude': 148.259,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded0'),
#  'confidence': 61,
#  'date': '2018-08-14',
#  'datetime': '2018-08-14T04:11:00',
#  'latitude': -38.0173,
#  'longitude': 144.0571,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded1'),
#  'confidence': 67,
#  'date': '2018-08-14',
#  'datetime': '2018-08-14T04:10:20',
#  'latitude': -37.4754,
#  'longitude': 148.161,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded2'),
#  'confidence': 61,
#  'date': '2018-08-14',
#  'datetime': '2018-08-14T04:09:30',
#  'latitude': -37.443,
#  'longitude': 147.3064,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded3'),
#  'confidence': 58,
#  'date': '2018-08-14',
#  'datetime': '2018-08-14T04:07:50',
#  'latitude': -37.7836,
#  'longitude': 143.9688,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded4'),
#  'confidence': 54,
#  'date': '2018-08-13',
#  'datetime': '2018-08-13T05:13:30',
#  'latitude': -34.848,
#  'longitude': 141.5002,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded8'),
#  'confidence': 63,
#  'date': '2018-08-13',
#  'datetime': '2018-08-13T05:05:00',
#  'latitude': -34.8425,
#  'longitude': 141.4933,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4ded9'),
#  'confidence': 63,
#  'date': '2018-08-13',
#  'datetime': '2018-08-13T05:03:10',
#  'latitude': -34.793,
#  'longitude': 141.5898,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dede'),
#  'confidence': 59,
#  'date': '2018-08-05',
#  'datetime': '2018-08-05T04:20:10',
#  'latitude': -37.8519,
#  'longitude': 147.2555,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4dee0'),
#  'confidence': 54,
#  'date': '2018-08-02',
#  'datetime': '2018-08-02T03:45:00',
#  'latitude': -37.491,
#  'longitude': 141.936,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4dee7'),
#  'confidence': 63,
#  'date': '2018-07-14',
#  'datetime': '2018-07-14T04:58:10',
#  'latitude': -38.5194,
#  'longitude': 143.4522,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dee8'),
#  'confidence': 61,
#  'date': '2018-07-14',
#  'datetime': '2018-07-14T04:50:20',
#  'latitude': -38.5233,
#  'longitude': 143.433,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4deeb'),
#  'confidence': 66,
#  'date': '2018-07-06',
#  'datetime': '2018-07-06T04:02:00',
#  'latitude': -37.8757,
#  'longitude': 143.428,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4deec'),
#  'confidence': 69,
#  'date': '2018-07-05',
#  'datetime': '2018-07-05T23:44:00',
#  'latitude': -38.4031,
#  'longitude': 147.0701,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4deed'),
#  'confidence': 57,
#  'date': '2018-07-04',
#  'datetime': '2018-07-04T04:14:00',
#  'latitude': -37.8067,
#  'longitude': 141.7598,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4def0'),
#  'confidence': 69,
#  'date': '2018-07-02',
#  'datetime': '2018-07-02T04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
#
#
# {'_id': ObjectId('60a352919343695b37c4def1'),
#  'confidence': 69,
#  'date': '2018-07-02',
#  'datetime': '2018-07-02T04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
#
#
# {'_id': ObjectId('60a352919343695b37c4def4'),
#  'confidence': 50,
#  'date': '2018-07-02',
#  'datetime': '2018-07-02T04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
#
#
# {'_id': ObjectId('60a352919343695b37c4def5'),
#  'confidence': 50,
#  'date': '2018-07-02',
#  'datetime': '2018-07-02T04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
#
#
# {'_id': ObjectId('60a352919343695b37c4def6'),
#  'confidence': 53,
#  'date': '2018-07-01',
#  'datetime': '2018-07-01T13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
#
#
# {'_id': ObjectId('60a352919343695b37c4def7'),
#  'confidence': 53,
#  'date': '2018-07-01',
#  'datetime': '2018-07-01T13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
#
#
# {'_id': ObjectId('60a352919343695b37c4def8'),
#  'confidence': 61,
#  'date': '2018-07-01',
#  'datetime': '2018-07-01T03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
#
#
# {'_id': ObjectId('60a352919343695b37c4def9'),
#  'confidence': 61,
#  'date': '2018-07-01',
#  'datetime': '2018-07-01T03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
#
#
# {'_id': ObjectId('60a352919343695b37c4df08'),
#  'confidence': 53,
#  'date': '2018-06-18',
#  'datetime': '2018-06-18T04:14:00',
#  'latitude': -37.8387,
#  'longitude': 144.6301,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df09'),
#  'confidence': 66,
#  'date': '2018-06-16',
#  'datetime': '2018-06-16T04:34:30',
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4df0a'),
#  'confidence': 64,
#  'date': '2018-06-16',
#  'datetime': '2018-06-16T04:26:10',
#  'latitude': -36.7084,
#  'longitude': 142.7354,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df0b'),
#  'confidence': 61,
#  'date': '2018-06-14',
#  'datetime': '2018-06-14T04:44:10',
#  'latitude': -36.2669,
#  'longitude': 143.1906,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4df0d'),
#  'confidence': 55,
#  'date': '2018-06-14',
#  'datetime': '2018-06-14T04:40:10',
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df0e'),
#  'confidence': 69,
#  'date': '2018-06-14',
#  'datetime': '2018-06-14T04:38:30',
#  'latitude': -36.059,
#  'longitude': 143.7718,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df0f'),
#  'confidence': 62,
#  'date': '2018-06-13',
#  'datetime': '2018-06-13T04:02:00',
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df10'),
#  'confidence': 62,
#  'date': '2018-06-11',
#  'datetime': '2018-06-11T04:09:40',
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df11'),
#  'confidence': 64,
#  'date': '2018-06-11',
#  'datetime': '2018-06-11T04:08:00',
#  'latitude': -37.6662,
#  'longitude': 142.9874,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df16'),
#  'confidence': 55,
#  'date': '2018-06-07',
#  'datetime': '2018-06-07T04:36:00',
#  'latitude': -36.1858,
#  'longitude': 143.885,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df18'),
#  'confidence': 68,
#  'date': '2018-06-07',
#  'datetime': '2018-06-07T04:35:40',
#  'latitude': -36.2111,
#  'longitude': 141.505,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df19'),
#  'confidence': 53,
#  'date': '2018-06-07',
#  'datetime': '2018-06-07T04:35:30',
#  'latitude': -36.5794,
#  'longitude': 142.5959,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df1c'),
#  'confidence': 61,
#  'date': '2018-06-07',
#  'datetime': '2018-06-07T04:32:10',
#  'latitude': -36.2229,
#  'longitude': 143.4245,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df1d'),
#  'confidence': 52,
#  'date': '2018-06-07',
#  'datetime': '2018-06-07T04:32:10',
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4df26'),
#  'confidence': 58,
#  'date': '2018-06-04',
#  'datetime': '2018-06-04T04:02:30',
#  'latitude': -37.4661,
#  'longitude': 143.2419,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df2a'),
#  'confidence': 54,
#  'date': '2018-06-04',
#  'datetime': '2018-06-04T04:02:10',
#  'latitude': -36.4422,
#  'longitude': 141.427,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df2b'),
#  'confidence': 59,
#  'date': '2018-06-04',
#  'datetime': '2018-06-04T04:02:10',
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df31'),
#  'confidence': 64,
#  'date': '2018-06-02',
#  'datetime': '2018-06-02T04:14:40',
#  'latitude': -36.2032,
#  'longitude': 145.3025,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df32'),
#  'confidence': 65,
#  'date': '2018-06-02',
#  'datetime': '2018-06-02T04:14:10',
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df37'),
#  'confidence': 62,
#  'date': '2018-06-02',
#  'datetime': '2018-06-02T04:14:10',
#  'latitude': -36.6312,
#  'longitude': 142.5058,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df3c'),
#  'confidence': 60,
#  'date': '2018-05-26',
#  'datetime': '2018-05-26T04:08:10',
#  'latitude': -36.3334,
#  'longitude': 141.1515,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df3f'),
#  'confidence': 61,
#  'date': '2018-05-24',
#  'datetime': '2018-05-24T04:20:20',
#  'latitude': -37.0585,
#  'longitude': 143.8589,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df40'),
#  'confidence': 59,
#  'date': '2018-05-24',
#  'datetime': '2018-05-24T00:04:20',
#  'latitude': -36.6859,
#  'longitude': 146.8907,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df41'),
#  'confidence': 56,
#  'date': '2018-05-24',
#  'datetime': '2018-05-24T00:01:50',
#  'latitude': -36.575,
#  'longitude': 146.6668,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df45'),
#  'confidence': 68,
#  'date': '2018-05-23',
#  'datetime': '2018-05-23T00:54:50',
#  'latitude': -37.9004,
#  'longitude': 141.0921,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df47'),
#  'confidence': 66,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T15:30:20',
#  'latitude': -36.6396,
#  'longitude': 146.8973,
#  'surface_temperature_celcius': 36}
#
#
# {'_id': ObjectId('60a352919343695b37c4df49'),
#  'confidence': 59,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:42:20',
#  'latitude': -36.7889,
#  'longitude': 146.6495,
#  'surface_temperature_celcius': 49}
#
#
# {'_id': ObjectId('60a352919343695b37c4df4a'),
#  'confidence': 63,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:38:50',
#  'latitude': -36.4794,
#  'longitude': 144.5752,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df4b'),
#  'confidence': 52,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:37:20',
#  'latitude': -37.6198,
#  'longitude': 143.0357,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4df4d'),
#  'confidence': 58,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:34:50',
#  'latitude': -37.4857,
#  'longitude': 143.5322,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df52'),
#  'confidence': 53,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:32:50',
#  'latitude': -36.7842,
#  'longitude': 146.9658,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df5b'),
#  'confidence': 65,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -36.7871,
#  'longitude': 146.9604,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df5c'),
#  'confidence': 64,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.5158,
#  'longitude': 142.8257,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df5e'),
#  'confidence': 61,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.7287,
#  'longitude': 143.1682,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df5f'),
#  'confidence': 58,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.7379,
#  'longitude': 143.1706,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df64'),
#  'confidence': 61,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T00:13:00',
#  'latitude': -38.4322,
#  'longitude': 146.3208,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df65'),
#  'confidence': 66,
#  'date': '2018-05-22',
#  'datetime': '2018-05-22T00:13:00',
#  'latitude': -37.9077,
#  'longitude': 141.1101,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4df68'),
#  'confidence': 61,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T03:25:00',
#  'latitude': -36.1337,
#  'longitude': 146.1243,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df69'),
#  'confidence': 68,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.8431,
#  'longitude': 147.5395,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df6a'),
#  'confidence': 69,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.8403,
#  'longitude': 147.5354,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4df6b'),
#  'confidence': 64,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.1369,
#  'longitude': 146.116,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df6c'),
#  'confidence': 55,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T00:43:10',
#  'latitude': -37.164,
#  'longitude': 148.915,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df6d'),
#  'confidence': 66,
#  'date': '2018-05-18',
#  'datetime': '2018-05-18T00:38:10',
#  'latitude': -37.1521,
#  'longitude': 148.9446,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352919343695b37c4df70'),
#  'confidence': 53,
#  'date': '2018-05-16',
#  'datetime': '2018-05-16T03:37:40',
#  'latitude': -36.1875,
#  'longitude': 143.5158,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df71'),
#  'confidence': 56,
#  'date': '2018-05-16',
#  'datetime': '2018-05-16T03:32:50',
#  'latitude': -36.1887,
#  'longitude': 143.4722,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df72'),
#  'confidence': 61,
#  'date': '2018-05-16',
#  'datetime': '2018-05-16T00:48:40',
#  'latitude': -37.2465,
#  'longitude': 144.3795,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df74'),
#  'confidence': 64,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:35:20',
#  'latitude': -36.4437,
#  'longitude': 143.5726,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df75'),
#  'confidence': 59,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:34:50',
#  'latitude': -36.3987,
#  'longitude': 142.6332,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df79'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:33:20',
#  'latitude': -36.3065,
#  'longitude': 141.4495,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df7a'),
#  'confidence': 66,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:33:20',
#  'latitude': -37.5074,
#  'longitude': 142.976,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4df7d'),
#  'confidence': 55,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -37.2622,
#  'longitude': 144.3704,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df7e'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.3111,
#  'longitude': 143.7704,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4df7f'),
#  'confidence': 51,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.7159,
#  'longitude': 141.4716,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4df80'),
#  'confidence': 51,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.5963,
#  'longitude': 144.0066,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4df88'),
#  'confidence': 60,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:29:40',
#  'latitude': -36.4216,
#  'longitude': 141.2799,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4df89'),
#  'confidence': 64,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:29:40',
#  'latitude': -36.4317,
#  'longitude': 143.0967,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8a'),
#  'confidence': 63,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:29:30',
#  'latitude': -36.2538,
#  'longitude': 145.5929,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8b'),
#  'confidence': 66,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:29:30',
#  'latitude': -36.437,
#  'longitude': 144.1478,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8c'),
#  'confidence': 55,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:29:10',
#  'latitude': -36.6217,
#  'longitude': 142.0944,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8d'),
#  'confidence': 66,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:28:40',
#  'latitude': -36.3652,
#  'longitude': 141.3508,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8e'),
#  'confidence': 56,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:28:20',
#  'latitude': -36.8241,
#  'longitude': 145.1274,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df8f'),
#  'confidence': 63,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:28:10',
#  'latitude': -36.3296,
#  'longitude': 141.7522,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df90'),
#  'confidence': 64,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:28:10',
#  'latitude': -35.7542,
#  'longitude': 142.5039,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4df99'),
#  'confidence': 67,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:27:10',
#  'latitude': -36.3019,
#  'longitude': 146.4343,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60a352919343695b37c4df9b'),
#  'confidence': 63,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:27:10',
#  'latitude': -36.3542,
#  'longitude': 141.0935,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4df9e'),
#  'confidence': 57,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:40',
#  'latitude': -35.6785,
#  'longitude': 143.5077,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4df9f'),
#  'confidence': 68,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:40',
#  'latitude': -36.6755,
#  'longitude': 141.5039,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfa6'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.3971,
#  'longitude': 142.6444,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfa8'),
#  'confidence': 56,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.4226,
#  'longitude': 143.0946,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfab'),
#  'confidence': 52,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.5646,
#  'longitude': 142.3068,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfae'),
#  'confidence': 64,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.7126,
#  'longitude': 141.6358,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfaf'),
#  'confidence': 63,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.4347,
#  'longitude': 143.5704,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfb2'),
#  'confidence': 68,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.7611,
#  'longitude': 141.6048,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfb3'),
#  'confidence': 65,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.5664,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfb5'),
#  'confidence': 60,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.6483,
#  'longitude': 142.4878,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfb9'),
#  'confidence': 66,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.86,
#  'longitude': 142.8137,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfba'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.3119,
#  'longitude': 146.4371,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfbc'),
#  'confidence': 59,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.6463,
#  'longitude': 144.7594,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfc0'),
#  'confidence': 51,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.2794,
#  'longitude': 143.5903,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfc3'),
#  'confidence': 66,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.2811,
#  'longitude': 143.8819,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfca'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.0411,
#  'longitude': 141.7071,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfcc'),
#  'confidence': 69,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -35.9903,
#  'longitude': 142.2708,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfd6'),
#  'confidence': 64,
#  'date': '2018-05-15',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.7481,
#  'longitude': 143.4151,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfdd'),
#  'confidence': 50,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:42:20',
#  'latitude': -36.353,
#  'longitude': 144.5977,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfde'),
#  'confidence': 69,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -36.4489,
#  'longitude': 144.1445,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfdf'),
#  'confidence': 52,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -34.9917,
#  'longitude': 141.8885,
#  'surface_temperature_celcius': 49}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfe0'),
#  'confidence': 69,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -36.4032,
#  'longitude': 144.0604,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfe3'),
#  'confidence': 56,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:40:20',
#  'latitude': -36.3883,
#  'longitude': 143.7526,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfe6'),
#  'confidence': 66,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:40:10',
#  'latitude': -36.5513,
#  'longitude': 144.1473,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4dfe9'),
#  'confidence': 66,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:39:10',
#  'latitude': -36.6361,
#  'longitude': 144.5124,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4dff0'),
#  'confidence': 62,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -37.1999,
#  'longitude': 143.6425,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4dff2'),
#  'confidence': 53,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -34.9959,
#  'longitude': 141.8635,
#  'surface_temperature_celcius': 49}
#
#
# {'_id': ObjectId('60a352919343695b37c4dff3'),
#  'confidence': 53,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -34.9843,
#  'longitude': 141.8736,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352919343695b37c4e001'),
#  'confidence': 57,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.8399,
#  'longitude': 142.6291,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4e002'),
#  'confidence': 50,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -35.708,
#  'longitude': 143.7987,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352919343695b37c4e007'),
#  'confidence': 68,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.3832,
#  'longitude': 143.7566,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4e008'),
#  'confidence': 59,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.304,
#  'longitude': 143.7445,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4e009'),
#  'confidence': 55,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.591,
#  'longitude': 141.7194,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4e00a'),
#  'confidence': 68,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.8377,
#  'longitude': 142.642,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4e00d'),
#  'confidence': 63,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.0518,
#  'longitude': 141.6846,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e00f'),
#  'confidence': 54,
#  'date': '2018-05-13',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.7321,
#  'longitude': 143.1978,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352919343695b37c4e010'),
#  'confidence': 64,
#  'date': '2018-05-12',
#  'datetime': '2018-05-12T04:02:30',
#  'latitude': -36.5375,
#  'longitude': 146.0866,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e013'),
#  'confidence': 66,
#  'date': '2018-05-12',
#  'datetime': '2018-05-12T03:56:10',
#  'latitude': -34.9194,
#  'longitude': 140.9678,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e015'),
#  'confidence': 64,
#  'date': '2018-05-12',
#  'datetime': '2018-05-12T03:56:10',
#  'latitude': -36.4061,
#  'longitude': 143.0987,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e019'),
#  'confidence': 67,
#  'date': '2018-05-12',
#  'datetime': '2018-05-12T01:15:30',
#  'latitude': -37.9774,
#  'longitude': 141.2029,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352919343695b37c4e01f'),
#  'confidence': 65,
#  'date': '2018-05-11',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.1188,
#  'longitude': 145.156,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e021'),
#  'confidence': 54,
#  'date': '2018-05-11',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -35.4173,
#  'longitude': 143.2041,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4e024'),
#  'confidence': 54,
#  'date': '2018-05-11',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.3909,
#  'longitude': 141.1843,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4e02a'),
#  'confidence': 58,
#  'date': '2018-05-11',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.4713,
#  'longitude': 144.4747,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4e02c'),
#  'confidence': 68,
#  'date': '2018-05-11',
#  'datetime': '2018-05-11T00:33:20',
#  'latitude': -38.5675,
#  'longitude': 146.4563,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4e031'),
#  'confidence': 66,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:14:30',
#  'latitude': -36.7937,
#  'longitude': 141.3669,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e034'),
#  'confidence': 55,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:14:10',
#  'latitude': -36.2359,
#  'longitude': 141.3007,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4e036'),
#  'confidence': 65,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:14:00',
#  'latitude': -36.587,
#  'longitude': 142.87,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e03c'),
#  'confidence': 69,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.9731,
#  'longitude': 143.9437,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4e03e'),
#  'confidence': 63,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.7532,
#  'longitude': 141.7986,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e041'),
#  'confidence': 64,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.6258,
#  'longitude': 142.9987,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352919343695b37c4e042'),
#  'confidence': 67,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:10:10',
#  'latitude': -36.0236,
#  'longitude': 143.2158,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e043'),
#  'confidence': 59,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:10:00',
#  'latitude': -37.4574,
#  'longitude': 142.9354,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4e044'),
#  'confidence': 57,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:09:50',
#  'latitude': -37.3317,
#  'longitude': 143.822,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4e045'),
#  'confidence': 57,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -36.6329,
#  'longitude': 142.9903,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e046'),
#  'confidence': 66,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -36.884,
#  'longitude': 145.8938,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e047'),
#  'confidence': 56,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -37.5263,
#  'longitude': 143.0882,
#  'surface_temperature_celcius': 53}
#
#
# {'_id': ObjectId('60a352919343695b37c4e04a'),
#  'confidence': 62,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:09:20',
#  'latitude': -36.2455,
#  'longitude': 141.3205,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352919343695b37c4e04c'),
#  'confidence': 56,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:50',
#  'latitude': -37.7461,
#  'longitude': 142.7369,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352919343695b37c4e056'),
#  'confidence': 60,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:20',
#  'latitude': -38.294,
#  'longitude': 143.7227,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4e059'),
#  'confidence': 61,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.6659,
#  'longitude': 143.186,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4e05a'),
#  'confidence': 63,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.7506,
#  'longitude': 142.7265,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352919343695b37c4e05d'),
#  'confidence': 60,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.959,
#  'longitude': 143.5497,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352919343695b37c4e05f'),
#  'confidence': 68,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -38.0189,
#  'longitude': 143.6406,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352919343695b37c4e064'),
#  'confidence': 68,
#  'date': '2018-05-10',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -38.2481,
# ...
#  'datetime': '2018-04-04T04:39:40',
#  'latitude': -36.937,
#  'longitude': 142.1176,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6dc'),
#  'confidence': 50,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:38:10',
#  'latitude': -36.6951,
#  'longitude': 145.424,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6e0'),
#  'confidence': 67,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:36:30',
#  'latitude': -37.6714,
#  'longitude': 144.2154,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6e2'),
#  'confidence': 63,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:36:30',
#  'latitude': -38.0494,
#  'longitude': 143.9141,
#  'surface_temperature_celcius': 58}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6f0'),
#  'confidence': 54,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:34:20',
#  'latitude': -38.4879,
#  'longitude': 143.9971,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6f6'),
#  'confidence': 63,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:33:30',
#  'latitude': -37.1744,
#  'longitude': 143.9256,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6f8'),
#  'confidence': 69,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:33:30',
#  'latitude': -36.4918,
#  'longitude': 142.2465,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352929343695b37c4e6fd'),
#  'confidence': 66,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:33:10',
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
#
#
# {'_id': ObjectId('60a352929343695b37c4e701'),
#  'confidence': 53,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:33:10',
#  'latitude': -36.1439,
#  'longitude': 145.832,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352929343695b37c4e708'),
#  'confidence': 54,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:50',
#  'latitude': -36.7009,
#  'longitude': 141.541,
#  'surface_temperature_celcius': 49}
#
#
# {'_id': ObjectId('60a352929343695b37c4e70f'),
#  'confidence': 55,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.4611,
#  'longitude': 143.146,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352929343695b37c4e712'),
#  'confidence': 53,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.3539,
#  'longitude': 142.1894,
#  'surface_temperature_celcius': 53}
#
#
# {'_id': ObjectId('60a352929343695b37c4e716'),
#  'confidence': 66,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -37.0081,
#  'longitude': 141.7654,
#  'surface_temperature_celcius': 62}
#
#
# {'_id': ObjectId('60a352929343695b37c4e719'),
#  'confidence': 64,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.2889,
#  'longitude': 141.7692,
#  'surface_temperature_celcius': 51}
#
#
# {'_id': ObjectId('60a352929343695b37c4e71b'),
#  'confidence': 67,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.6228,
#  'longitude': 142.428,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e71d'),
#  'confidence': 60,
#  'date': '2018-04-04',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -38.1177,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352929343695b37c4e733'),
#  'confidence': 69,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:53:50',
#  'latitude': -37.8668,
#  'longitude': 143.0472,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e734'),
#  'confidence': 68,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:53:40',
#  'latitude': -37.7602,
#  'longitude': 143.382,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e736'),
#  'confidence': 66,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:53:30',
#  'latitude': -37.7885,
#  'longitude': 142.9509,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e742'),
#  'confidence': 66,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:52:10',
#  'latitude': -37.8717,
#  'longitude': 143.2566,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e747'),
#  'confidence': 67,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:51:10',
#  'latitude': -37.8011,
#  'longitude': 144.7343,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e74d'),
#  'confidence': 67,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.0241,
#  'longitude': 141.5163,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e74e'),
#  'confidence': 66,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.2912,
#  'longitude': 143.543,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e74f'),
#  'confidence': 52,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.313,
#  'longitude': 146.1561,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e750'),
#  'confidence': 56,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -38.0226,
#  'longitude': 143.6739,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352929343695b37c4e755'),
#  'confidence': 56,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.8089,
#  'longitude': 145.9555,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352929343695b37c4e756'),
#  'confidence': 62,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.9009,
#  'longitude': 143.6217,
#  'surface_temperature_celcius': 45}
#
#
# {'_id': ObjectId('60a352929343695b37c4e758'),
#  'confidence': 69,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.7836,
#  'longitude': 142.9437,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e75c'),
#  'confidence': 52,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.0484,
#  'longitude': 141.6245,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352929343695b37c4e75d'),
#  'confidence': 68,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -36.911,
#  'longitude': 142.1445,
#  'surface_temperature_celcius': 47}
#
#
# {'_id': ObjectId('60a352929343695b37c4e765'),
#  'confidence': 67,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T01:11:00',
#  'latitude': -34.2536,
#  'longitude': 141.6199,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e769'),
#  'confidence': 57,
#  'date': '2018-04-03',
#  'datetime': '2018-04-03T01:07:00',
#  'latitude': -34.2614,
#  'longitude': 141.6412,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e76a'),
#  'confidence': 60,
#  'date': '2018-04-02',
#  'datetime': '2018-04-02T04:53:30',
#  'latitude': -36.3872,
#  'longitude': 145.3858,
#  'surface_temperature_celcius': 40}
#
#
# {'_id': ObjectId('60a352929343695b37c4e76d'),
#  'confidence': 63,
#  'date': '2018-04-02',
#  'datetime': '2018-04-02T04:45:10',
#  'latitude': -36.494,
#  'longitude': 145.4522,
#  'surface_temperature_celcius': 41}
#
#
# {'_id': ObjectId('60a352929343695b37c4e76e'),
#  'confidence': 60,
#  'date': '2018-04-02',
#  'datetime': '2018-04-02T00:24:50',
#  'latitude': -37.324,
#  'longitude': 146.1647,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e773'),
#  'confidence': 58,
#  'date': '2018-04-01',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.2044,
#  'longitude': 145.7706,
#  'surface_temperature_celcius': 51}
#
#
# {'_id': ObjectId('60a352929343695b37c4e774'),
#  'confidence': 57,
#  'date': '2018-04-01',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.5245,
#  'longitude': 143.1556,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e775'),
#  'confidence': 50,
#  'date': '2018-04-01',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.1002,
#  'longitude': 147.6494,
#  'surface_temperature_celcius': 39}
#
#
# {'_id': ObjectId('60a352929343695b37c4e77f'),
#  'confidence': 68,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:50',
#  'latitude': -36.1649,
#  'longitude': 145.9352,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e780'),
#  'confidence': 68,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:40',
#  'latitude': -36.0436,
#  'longitude': 145.7964,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e786'),
#  'confidence': 52,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -36.7134,
#  'longitude': 145.2151,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352929343695b37c4e787'),
#  'confidence': 61,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -36.7028,
#  'longitude': 145.2519,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e788'),
#  'confidence': 51,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -37.561,
#  'longitude': 143.242,
#  'surface_temperature_celcius': 38}
#
#
# {'_id': ObjectId('60a352929343695b37c4e789'),
#  'confidence': 56,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -37.982,
#  'longitude': 143.6422,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352929343695b37c4e78b'),
#  'confidence': 51,
#  'date': '2018-03-31',
#  'datetime': '2018-03-31T00:36:30',
#  'latitude': -34.2568,
#  'longitude': 141.64,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352929343695b37c4e78c'),
#  'confidence': 69,
#  'date': '2018-03-29',
#  'datetime': '2018-03-29T00:48:40',
#  'latitude': -34.2648,
#  'longitude': 141.6325,
#  'surface_temperature_celcius': 51}
#
#
# {'_id': ObjectId('60a352929343695b37c4e79f'),
#  'confidence': 53,
#  'date': '2018-03-28',
#  'datetime': '2018-03-28T04:29:30',
#  'latitude': -37.6195,
#  'longitude': 143.4212,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7b2'),
#  'confidence': 63,
#  'date': '2018-03-28',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -37.6376,
#  'longitude': 143.4255,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7bc'),
#  'confidence': 69,
#  'date': '2018-03-28',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -36.4422,
#  'longitude': 141.4172,
#  'surface_temperature_celcius': 46}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7c2'),
#  'confidence': 55,
#  'date': '2018-03-28',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -34.342,
#  'longitude': 141.6548,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7c6'),
#  'confidence': 68,
#  'date': '2018-03-26',
#  'datetime': '2018-03-26T04:41:10',
#  'latitude': -38.1131,
#  'longitude': 143.7173,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7d0'),
#  'confidence': 60,
#  'date': '2018-03-26',
#  'datetime': '2018-03-26T04:39:10',
#  'latitude': -37.8469,
#  'longitude': 143.5343,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7d2'),
#  'confidence': 67,
#  'date': '2018-03-26',
#  'datetime': '2018-03-26T04:39:10',
#  'latitude': -37.1956,
#  'longitude': 141.0252,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7d5'),
#  'confidence': 62,
#  'date': '2018-03-25',
#  'datetime': '2018-03-25T04:03:10',
#  'latitude': -37.8992,
#  'longitude': 143.4534,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e0'),
#  'confidence': 57,
#  'date': '2018-03-25',
#  'datetime': '2018-03-25T03:56:40',
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e1'),
#  'confidence': 65,
#  'date': '2018-03-24',
#  'datetime': '2018-03-24T04:58:00',
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e2'),
#  'confidence': 55,
#  'date': '2018-03-24',
#  'datetime': '2018-03-24T04:56:10',
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e4'),
#  'confidence': 58,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e6'),
#  'confidence': 63,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e7'),
#  'confidence': 64,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:36:00',
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7e9'),
#  'confidence': 59,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:35:00',
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7ea'),
#  'confidence': 60,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:33:50',
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7eb'),
#  'confidence': 61,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7ec'),
#  'confidence': 53,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7ed'),
#  'confidence': 61,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:33:10',
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7f1'),
#  'confidence': 66,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T04:32:50',
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7f7'),
#  'confidence': 60,
#  'date': '2018-03-19',
#  'datetime': '2018-03-19T00:12:50',
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e7f8'),
#  'confidence': 64,
#  'date': '2018-03-18',
#  'datetime': '2018-03-18T13:16:50',
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
#
#
# {'_id': ObjectId('60a352929343695b37c4e803'),
#  'confidence': 52,
#  'date': '2018-03-15',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e804'),
#  'confidence': 66,
#  'date': '2018-03-15',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e805'),
#  'confidence': 51,
#  'date': '2018-03-15',
#  'datetime': '2018-03-15T00:42:40',
#  'latitude': -37.002,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e812'),
#  'confidence': 56,
#  'date': '2018-03-13',
#  'datetime': '2018-03-13T23:58:50',
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352929343695b37c4e813'),
#  'confidence': 52,
#  'date': '2018-03-13',
#  'datetime': '2018-03-13T12:57:00',
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
#
#
# {'_id': ObjectId('60a352929343695b37c4e81e'),
#  'confidence': 55,
#  'date': '2018-03-10',
#  'datetime': '2018-03-10T04:43:00',
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
#
#
# {'_id': ObjectId('60a352929343695b37c4e81f'),
#  'confidence': 54,
#  'date': '2018-03-10',
#  'datetime': '2018-03-10T04:42:30',
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
#
#
# {'_id': ObjectId('60a352929343695b37c4e822'),
#  'confidence': 54,
#  'date': '2018-03-09',
#  'datetime': '2018-03-09T03:57:00',
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
#
#
# {'_id': ObjectId('60a352929343695b37c4e824'),
#  'confidence': 68,
#  'date': '2018-03-08',
#  'datetime': '2018-03-08T04:51:00',
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}

# %%
# h. Find the average surface temperature (°C) for each day. You are required to only display average 
#    surface temperature (°C) and the date in the output.

cursor = db.climate.aggregate([
    {"$lookup" : {
        "from" : "hotspot",
        "localField": "_id",
        "foreignField": "foreign_key",
        "as": "from_hotspot_historic"
        }},
    {"$unwind" : {
        "path":"$from_hotspot_historic",
        "preserveNullAndEmptyArrays":True
    }},
    {"$group" : {
        "_id" : "$date",
        "surface_temperature_average" : {"$avg":"$from_hotspot_historic.surface_temperature_celcius"}
    }},
    {"$project" : {
        "_id":0,
        'date':"$_id",
        'surface_temperature_average':1
    }},
    {"$sort": {"date":1}}
])

for i in cursor:
    pprint(i)
# Out:
# {'date': '2017-12-31', 'surface_temperature_average': None}
# {'date': '2018-01-01', 'surface_temperature_average': None}
# {'date': '2018-01-02', 'surface_temperature_average': None}
# {'date': '2018-01-03', 'surface_temperature_average': None}
# {'date': '2018-01-04', 'surface_temperature_average': None}
# {'date': '2018-01-05', 'surface_temperature_average': None}
# {'date': '2018-01-06', 'surface_temperature_average': None}
# {'date': '2018-01-07', 'surface_temperature_average': None}
# {'date': '2018-01-08', 'surface_temperature_average': None}
# {'date': '2018-01-09', 'surface_temperature_average': None}
# {'date': '2018-01-10', 'surface_temperature_average': None}
# {'date': '2018-01-11', 'surface_temperature_average': None}
# {'date': '2018-01-12', 'surface_temperature_average': None}
# {'date': '2018-01-13', 'surface_temperature_average': None}
# {'date': '2018-01-14', 'surface_temperature_average': None}
# {'date': '2018-01-15', 'surface_temperature_average': None}
# {'date': '2018-01-16', 'surface_temperature_average': None}
# {'date': '2018-01-17', 'surface_temperature_average': None}
# {'date': '2018-01-18', 'surface_temperature_average': None}
# {'date': '2018-01-19', 'surface_temperature_average': None}
# {'date': '2018-01-20', 'surface_temperature_average': None}
# {'date': '2018-01-21', 'surface_temperature_average': None}
# {'date': '2018-01-22', 'surface_temperature_average': None}
# {'date': '2018-01-23', 'surface_temperature_average': None}
# {'date': '2018-01-24', 'surface_temperature_average': None}
# {'date': '2018-01-25', 'surface_temperature_average': None}
# {'date': '2018-01-26', 'surface_temperature_average': None}
# {'date': '2018-01-27', 'surface_temperature_average': None}
# {'date': '2018-01-28', 'surface_temperature_average': None}
# {'date': '2018-01-29', 'surface_temperature_average': None}
# {'date': '2018-01-30', 'surface_temperature_average': None}
# {'date': '2018-01-31', 'surface_temperature_average': None}
# {'date': '2018-02-01', 'surface_temperature_average': None}
# {'date': '2018-02-02', 'surface_temperature_average': None}
# {'date': '2018-02-03', 'surface_temperature_average': None}
# {'date': '2018-02-04', 'surface_temperature_average': None}
# {'date': '2018-02-05', 'surface_temperature_average': None}
# {'date': '2018-02-06', 'surface_temperature_average': None}
# {'date': '2018-02-07', 'surface_temperature_average': None}
# {'date': '2018-02-08', 'surface_temperature_average': None}
# {'date': '2018-02-09', 'surface_temperature_average': None}
# {'date': '2018-02-10', 'surface_temperature_average': None}
# {'date': '2018-02-11', 'surface_temperature_average': None}
# {'date': '2018-02-12', 'surface_temperature_average': None}
# {'date': '2018-02-13', 'surface_temperature_average': None}
# {'date': '2018-02-14', 'surface_temperature_average': None}
# {'date': '2018-02-15', 'surface_temperature_average': None}
# {'date': '2018-02-16', 'surface_temperature_average': None}
# {'date': '2018-02-17', 'surface_temperature_average': None}
# {'date': '2018-02-18', 'surface_temperature_average': None}
# {'date': '2018-02-19', 'surface_temperature_average': None}
# {'date': '2018-02-20', 'surface_temperature_average': None}
# {'date': '2018-02-21', 'surface_temperature_average': None}
# {'date': '2018-02-22', 'surface_temperature_average': None}
# {'date': '2018-02-23', 'surface_temperature_average': None}
# {'date': '2018-02-24', 'surface_temperature_average': None}
# {'date': '2018-02-25', 'surface_temperature_average': None}
# {'date': '2018-02-26', 'surface_temperature_average': None}
# {'date': '2018-02-27', 'surface_temperature_average': None}
# {'date': '2018-02-28', 'surface_temperature_average': None}
# {'date': '2018-03-01', 'surface_temperature_average': None}
# {'date': '2018-03-02', 'surface_temperature_average': None}
# {'date': '2018-03-03', 'surface_temperature_average': None}
# {'date': '2018-03-04', 'surface_temperature_average': None}
# {'date': '2018-03-05', 'surface_temperature_average': None}
# {'date': '2018-03-06', 'surface_temperature_average': 60.5}
# {'date': '2018-03-07', 'surface_temperature_average': 64.0}
# {'date': '2018-03-08', 'surface_temperature_average': 51.5}
# {'date': '2018-03-09', 'surface_temperature_average': 46.666666666666664}
# {'date': '2018-03-10', 'surface_temperature_average': 69.375}
# {'date': '2018-03-11', 'surface_temperature_average': None}
# {'date': '2018-03-12', 'surface_temperature_average': 88.2}
# {'date': '2018-03-13', 'surface_temperature_average': 38.5}
# {'date': '2018-03-14', 'surface_temperature_average': 65.6}
# {'date': '2018-03-15', 'surface_temperature_average': 46.0}
# {'date': '2018-03-16', 'surface_temperature_average': None}
# {'date': '2018-03-17', 'surface_temperature_average': 59.5}
# {'date': '2018-03-18', 'surface_temperature_average': 79.33333333333333}
# {'date': '2018-03-19', 'surface_temperature_average': 65.57142857142857}
# {'date': '2018-03-20', 'surface_temperature_average': None}
# {'date': '2018-03-21', 'surface_temperature_average': None}
# {'date': '2018-03-22', 'surface_temperature_average': None}
# {'date': '2018-03-23', 'surface_temperature_average': None}
# {'date': '2018-03-24', 'surface_temperature_average': 49.0}
# {'date': '2018-03-25', 'surface_temperature_average': 66.0}
# {'date': '2018-03-26', 'surface_temperature_average': 56.88235294117647}
# {'date': '2018-03-27', 'surface_temperature_average': None}
# {'date': '2018-03-28', 'surface_temperature_average': 60.925925925925924}
# {'date': '2018-03-29', 'surface_temperature_average': 51.0}
# {'date': '2018-03-30', 'surface_temperature_average': None}
# {'date': '2018-03-31', 'surface_temperature_average': 48.72727272727273}
# {'date': '2018-04-01', 'surface_temperature_average': 46.714285714285715}
# {'date': '2018-04-02', 'surface_temperature_average': 45.2}
# {'date': '2018-04-03', 'surface_temperature_average': 58.44444444444444}
# {'date': '2018-04-04', 'surface_temperature_average': 62.57303370786517}
# {'date': '2018-04-05', 'surface_temperature_average': 53.142857142857146}
# {'date': '2018-04-06', 'surface_temperature_average': 61.71186440677966}
# {'date': '2018-04-07', 'surface_temperature_average': 50.69230769230769}
# {'date': '2018-04-08', 'surface_temperature_average': 60.75}
# {'date': '2018-04-09', 'surface_temperature_average': None}
# {'date': '2018-04-10', 'surface_temperature_average': None}
# {'date': '2018-04-11', 'surface_temperature_average': 46.291666666666664}
# {'date': '2018-04-12', 'surface_temperature_average': 52.69565217391305}
# {'date': '2018-04-13', 'surface_temperature_average': 58.57983193277311}
# {'date': '2018-04-14', 'surface_temperature_average': 61.94444444444444}
# {'date': '2018-04-15', 'surface_temperature_average': 59.57971014492754}
# {'date': '2018-04-16', 'surface_temperature_average': 48.72222222222222}
# {'date': '2018-04-17', 'surface_temperature_average': 50.921052631578945}
# {'date': '2018-04-18', 'surface_temperature_average': 53.36615384615384}
# {'date': '2018-04-19', 'surface_temperature_average': 54.16}
# {'date': '2018-04-20', 'surface_temperature_average': 56.58064516129032}
# {'date': '2018-04-21', 'surface_temperature_average': None}
# {'date': '2018-04-22', 'surface_temperature_average': 54.5}
# {'date': '2018-04-23', 'surface_temperature_average': 53.89473684210526}
# {'date': '2018-04-24', 'surface_temperature_average': 59.375}
# {'date': '2018-04-25', 'surface_temperature_average': 48.666666666666664}
# {'date': '2018-04-26', 'surface_temperature_average': 34.0}
# {'date': '2018-04-27', 'surface_temperature_average': None}
# {'date': '2018-04-28', 'surface_temperature_average': None}
# {'date': '2018-04-29', 'surface_temperature_average': 63.0}
# {'date': '2018-04-30', 'surface_temperature_average': None}
# {'date': '2018-05-01', 'surface_temperature_average': 68.4}
# {'date': '2018-05-02', 'surface_temperature_average': 55.6}
# {'date': '2018-05-03', 'surface_temperature_average': 56.796875}
# {'date': '2018-05-04', 'surface_temperature_average': 56.80740740740741}
# {'date': '2018-05-05', 'surface_temperature_average': 51.70967741935484}
# {'date': '2018-05-06', 'surface_temperature_average': 57.529411764705884}
# {'date': '2018-05-07', 'surface_temperature_average': 50.333333333333336}
# {'date': '2018-05-08', 'surface_temperature_average': 56.291666666666664}
# {'date': '2018-05-09', 'surface_temperature_average': 42.46153846153846}
# {'date': '2018-05-10', 'surface_temperature_average': 52.86842105263158}
# {'date': '2018-05-11', 'surface_temperature_average': 59.36842105263158}
# {'date': '2018-05-12', 'surface_temperature_average': 51.5}
# {'date': '2018-05-13', 'surface_temperature_average': 58.611111111111114}
# {'date': '2018-05-14', 'surface_temperature_average': 49.0}
# {'date': '2018-05-15', 'surface_temperature_average': 53.950980392156865}
# {'date': '2018-05-16', 'surface_temperature_average': 39.666666666666664}
# {'date': '2018-05-17', 'surface_temperature_average': 52.0}
# {'date': '2018-05-18', 'surface_temperature_average': 44.142857142857146}
# {'date': '2018-05-19', 'surface_temperature_average': None}
# {'date': '2018-05-20', 'surface_temperature_average': None}
# {'date': '2018-05-21', 'surface_temperature_average': None}
# {'date': '2018-05-22', 'surface_temperature_average': 54.484848484848484}
# {'date': '2018-05-23', 'surface_temperature_average': 51.2}
# {'date': '2018-05-24', 'surface_temperature_average': 40.333333333333336}
# {'date': '2018-05-25', 'surface_temperature_average': None}
# {'date': '2018-05-26', 'surface_temperature_average': 49.5}
# {'date': '2018-05-27', 'surface_temperature_average': None}
# {'date': '2018-05-28', 'surface_temperature_average': None}
# {'date': '2018-05-29', 'surface_temperature_average': None}
# {'date': '2018-05-30', 'surface_temperature_average': None}
# {'date': '2018-05-31', 'surface_temperature_average': None}
# {'date': '2018-06-01', 'surface_temperature_average': 54.0}
# {'date': '2018-06-02', 'surface_temperature_average': 47.72727272727273}
# {'date': '2018-06-03', 'surface_temperature_average': 47.0}
# {'date': '2018-06-04', 'surface_temperature_average': 52.22222222222222}
# {'date': '2018-06-05', 'surface_temperature_average': None}
# {'date': '2018-06-06', 'surface_temperature_average': None}
# {'date': '2018-06-07', 'surface_temperature_average': 51.857142857142854}
# {'date': '2018-06-08', 'surface_temperature_average': None}
# {'date': '2018-06-09', 'surface_temperature_average': 49.0}
# {'date': '2018-06-10', 'surface_temperature_average': None}
# {'date': '2018-06-11', 'surface_temperature_average': 41.5}
# {'date': '2018-06-12', 'surface_temperature_average': None}
# {'date': '2018-06-13', 'surface_temperature_average': 41.0}
# {'date': '2018-06-14', 'surface_temperature_average': 53.25}
# {'date': '2018-06-15', 'surface_temperature_average': None}
# {'date': '2018-06-16', 'surface_temperature_average': 42.5}
# {'date': '2018-06-17', 'surface_temperature_average': None}
# {'date': '2018-06-18', 'surface_temperature_average': 42.0}
# {'date': '2018-06-19', 'surface_temperature_average': None}
# {'date': '2018-06-20', 'surface_temperature_average': 71.16666666666667}
# {'date': '2018-06-21', 'surface_temperature_average': None}
# {'date': '2018-06-22', 'surface_temperature_average': 46.0}
# {'date': '2018-06-23', 'surface_temperature_average': None}
# {'date': '2018-06-24', 'surface_temperature_average': None}
# {'date': '2018-06-25', 'surface_temperature_average': None}
# {'date': '2018-06-26', 'surface_temperature_average': None}
# {'date': '2018-06-27', 'surface_temperature_average': None}
# {'date': '2018-06-28', 'surface_temperature_average': None}
# {'date': '2018-06-29', 'surface_temperature_average': None}
# {'date': '2018-06-30', 'surface_temperature_average': 44.333333333333336}
# {'date': '2018-07-01', 'surface_temperature_average': 30.5}
# {'date': '2018-07-02', 'surface_temperature_average': 43.5}
# {'date': '2018-07-03', 'surface_temperature_average': None}
# {'date': '2018-07-04', 'surface_temperature_average': 40.0}
# {'date': '2018-07-05', 'surface_temperature_average': 45.0}
# {'date': '2018-07-06', 'surface_temperature_average': 56.0}
# {'date': '2018-07-07', 'surface_temperature_average': None}
# {'date': '2018-07-08', 'surface_temperature_average': None}
# {'date': '2018-07-09', 'surface_temperature_average': None}
# {'date': '2018-07-10', 'surface_temperature_average': None}
# {'date': '2018-07-11', 'surface_temperature_average': None}
# {'date': '2018-07-12', 'surface_temperature_average': None}
# {'date': '2018-07-13', 'surface_temperature_average': None}
# {'date': '2018-07-14', 'surface_temperature_average': 41.5}
# {'date': '2018-07-15', 'surface_temperature_average': None}
# {'date': '2018-07-16', 'surface_temperature_average': None}
# {'date': '2018-07-17', 'surface_temperature_average': None}
# {'date': '2018-07-18', 'surface_temperature_average': None}
# {'date': '2018-07-19', 'surface_temperature_average': None}
# {'date': '2018-07-20', 'surface_temperature_average': None}
# {'date': '2018-07-21', 'surface_temperature_average': None}
# {'date': '2018-07-22', 'surface_temperature_average': None}
# {'date': '2018-07-23', 'surface_temperature_average': None}
# {'date': '2018-07-24', 'surface_temperature_average': None}
# {'date': '2018-07-25', 'surface_temperature_average': None}
# {'date': '2018-07-26', 'surface_temperature_average': None}
# {'date': '2018-07-27', 'surface_temperature_average': None}
# {'date': '2018-07-28', 'surface_temperature_average': None}
# {'date': '2018-07-29', 'surface_temperature_average': 48.0}
# {'date': '2018-07-30', 'surface_temperature_average': None}
# {'date': '2018-07-31', 'surface_temperature_average': 47.0}
# {'date': '2018-08-01', 'surface_temperature_average': 58.0}
# {'date': '2018-08-02', 'surface_temperature_average': 63.5}
# {'date': '2018-08-03', 'surface_temperature_average': None}
# {'date': '2018-08-04', 'surface_temperature_average': None}
# {'date': '2018-08-05', 'surface_temperature_average': 40.0}
# {'date': '2018-08-06', 'surface_temperature_average': None}
# {'date': '2018-08-07', 'surface_temperature_average': None}
# {'date': '2018-08-08', 'surface_temperature_average': None}
# {'date': '2018-08-09', 'surface_temperature_average': None}
# {'date': '2018-08-10', 'surface_temperature_average': 63.0}
# {'date': '2018-08-11', 'surface_temperature_average': None}
# {'date': '2018-08-12', 'surface_temperature_average': None}
# {'date': '2018-08-13', 'surface_temperature_average': 49.0}
# {'date': '2018-08-14', 'surface_temperature_average': 40.8}
# {'date': '2018-08-15', 'surface_temperature_average': None}
# {'date': '2018-08-16', 'surface_temperature_average': None}
# {'date': '2018-08-17', 'surface_temperature_average': None}
# {'date': '2018-08-18', 'surface_temperature_average': None}
# {'date': '2018-08-19', 'surface_temperature_average': None}
# {'date': '2018-08-20', 'surface_temperature_average': None}
# {'date': '2018-08-21', 'surface_temperature_average': None}
# {'date': '2018-08-22', 'surface_temperature_average': None}
# {'date': '2018-08-23', 'surface_temperature_average': None}
# {'date': '2018-08-24', 'surface_temperature_average': None}
# {'date': '2018-08-25', 'surface_temperature_average': None}
# {'date': '2018-08-26', 'surface_temperature_average': None}
# {'date': '2018-08-27', 'surface_temperature_average': None}
# {'date': '2018-08-28', 'surface_temperature_average': None}
# {'date': '2018-08-29', 'surface_temperature_average': None}
# {'date': '2018-08-30', 'surface_temperature_average': None}
# {'date': '2018-08-31', 'surface_temperature_average': None}
# {'date': '2018-09-01', 'surface_temperature_average': None}
# {'date': '2018-09-02', 'surface_temperature_average': None}
# {'date': '2018-09-03', 'surface_temperature_average': None}
# {'date': '2018-09-04', 'surface_temperature_average': None}
# {'date': '2018-09-05', 'surface_temperature_average': None}
# {'date': '2018-09-06', 'surface_temperature_average': None}
# {'date': '2018-09-07', 'surface_temperature_average': None}
# {'date': '2018-09-08', 'surface_temperature_average': None}
# {'date': '2018-09-09', 'surface_temperature_average': None}
# {'date': '2018-09-10', 'surface_temperature_average': 56.5}
# {'date': '2018-09-11', 'surface_temperature_average': None}
# {'date': '2018-09-12', 'surface_temperature_average': None}
# {'date': '2018-09-13', 'surface_temperature_average': None}
# {'date': '2018-09-14', 'surface_temperature_average': None}
# {'date': '2018-09-15', 'surface_temperature_average': None}
# {'date': '2018-09-16', 'surface_temperature_average': None}
# {'date': '2018-09-17', 'surface_temperature_average': None}
# {'date': '2018-09-18', 'surface_temperature_average': None}
# {'date': '2018-09-19', 'surface_temperature_average': None}
# {'date': '2018-09-20', 'surface_temperature_average': 63.6}
# {'date': '2018-09-21', 'surface_temperature_average': 40.5}
# {'date': '2018-09-22', 'surface_temperature_average': 45.0}
# {'date': '2018-09-23', 'surface_temperature_average': 52.73913043478261}
# {'date': '2018-09-24', 'surface_temperature_average': 53.57142857142857}
# {'date': '2018-09-25', 'surface_temperature_average': None}
# {'date': '2018-09-26', 'surface_temperature_average': 33.0}
# {'date': '2018-09-27', 'surface_temperature_average': 49.714285714285715}
# {'date': '2018-09-28', 'surface_temperature_average': None}
# {'date': '2018-09-29', 'surface_temperature_average': 43.0}
# {'date': '2018-09-30', 'surface_temperature_average': None}
# {'date': '2018-10-01', 'surface_temperature_average': 48.25}
# {'date': '2018-10-02', 'surface_temperature_average': 43.57142857142857}
# {'date': '2018-10-03', 'surface_temperature_average': 50.0}
# {'date': '2018-10-04', 'surface_temperature_average': 49.0}
# {'date': '2018-10-05', 'surface_temperature_average': None}
# {'date': '2018-10-06', 'surface_temperature_average': 44.0}
# {'date': '2018-10-07', 'surface_temperature_average': 42.0}
# {'date': '2018-10-08', 'surface_temperature_average': 41.0}
# {'date': '2018-10-09', 'surface_temperature_average': 44.0}
# {'date': '2018-10-10', 'surface_temperature_average': 53.333333333333336}
# {'date': '2018-10-11', 'surface_temperature_average': None}
# {'date': '2018-10-12', 'surface_temperature_average': None}
# {'date': '2018-10-13', 'surface_temperature_average': None}
# {'date': '2018-10-14', 'surface_temperature_average': None}
# {'date': '2018-10-15', 'surface_temperature_average': 72.66666666666667}
# {'date': '2018-10-16', 'surface_temperature_average': 36.0}
# {'date': '2018-10-17', 'surface_temperature_average': 51.6}
# {'date': '2018-10-18', 'surface_temperature_average': 52.166666666666664}
# {'date': '2018-10-19', 'surface_temperature_average': None}
# {'date': '2018-10-20', 'surface_temperature_average': 50.0}
# {'date': '2018-10-21', 'surface_temperature_average': 51.25}
# {'date': '2018-10-22', 'surface_temperature_average': None}
# {'date': '2018-10-23', 'surface_temperature_average': 38.0}
# {'date': '2018-10-24', 'surface_temperature_average': None}
# {'date': '2018-10-25', 'surface_temperature_average': None}
# {'date': '2018-10-26', 'surface_temperature_average': 44.6}
# {'date': '2018-10-27', 'surface_temperature_average': 50.4}
# {'date': '2018-10-28', 'surface_temperature_average': 56.0}
# {'date': '2018-10-29', 'surface_temperature_average': None}
# {'date': '2018-10-30', 'surface_temperature_average': None}
# {'date': '2018-10-31', 'surface_temperature_average': None}
# {'date': '2018-11-01', 'surface_temperature_average': None}
# {'date': '2018-11-02', 'surface_temperature_average': None}
# {'date': '2018-11-03', 'surface_temperature_average': None}
# {'date': '2018-11-04', 'surface_temperature_average': None}
# {'date': '2018-11-05', 'surface_temperature_average': 58.5}
# {'date': '2018-11-06', 'surface_temperature_average': None}
# {'date': '2018-11-07', 'surface_temperature_average': None}
# {'date': '2018-11-08', 'surface_temperature_average': 45.5}
# {'date': '2018-11-09', 'surface_temperature_average': 61.3}
# {'date': '2018-11-10', 'surface_temperature_average': None}
# {'date': '2018-11-11', 'surface_temperature_average': 46.25}
# {'date': '2018-11-12', 'surface_temperature_average': 53.0}
# {'date': '2018-11-13', 'surface_temperature_average': 47.0}
# {'date': '2018-11-14', 'surface_temperature_average': 52.0}
# {'date': '2018-11-15', 'surface_temperature_average': None}
# {'date': '2018-11-16', 'surface_temperature_average': None}
# {'date': '2018-11-17', 'surface_temperature_average': None}
# {'date': '2018-11-18', 'surface_temperature_average': None}
# {'date': '2018-11-19', 'surface_temperature_average': None}
# {'date': '2018-11-20', 'surface_temperature_average': None}
# {'date': '2018-11-21', 'surface_temperature_average': 59.0}
# {'date': '2018-11-22', 'surface_temperature_average': 61.5}
# {'date': '2018-11-23', 'surface_temperature_average': 58.8}
# {'date': '2018-11-24', 'surface_temperature_average': None}
# {'date': '2018-11-25', 'surface_temperature_average': None}
# {'date': '2018-11-26', 'surface_temperature_average': None}
# {'date': '2018-11-27', 'surface_temperature_average': None}
# {'date': '2018-11-28', 'surface_temperature_average': 42.0}
# {'date': '2018-11-29', 'surface_temperature_average': 60.625}
# {'date': '2018-11-30', 'surface_temperature_average': 52.41935483870968}
# {'date': '2018-12-01', 'surface_temperature_average': None}
# {'date': '2018-12-02', 'surface_temperature_average': None}
# {'date': '2018-12-03', 'surface_temperature_average': None}
# {'date': '2018-12-04', 'surface_temperature_average': None}
# {'date': '2018-12-05', 'surface_temperature_average': None}
# {'date': '2018-12-06', 'surface_temperature_average': None}
# {'date': '2018-12-07', 'surface_temperature_average': None}
# {'date': '2018-12-08', 'surface_temperature_average': 50.6}
# {'date': '2018-12-09', 'surface_temperature_average': 58.25}
# {'date': '2018-12-10', 'surface_temperature_average': 46.0}
# {'date': '2018-12-11', 'surface_temperature_average': None}
# {'date': '2018-12-12', 'surface_temperature_average': 44.0}
# {'date': '2018-12-13', 'surface_temperature_average': 60.0}
# {'date': '2018-12-14', 'surface_temperature_average': 70.0}
# {'date': '2018-12-15', 'surface_temperature_average': 39.0}
# {'date': '2018-12-16', 'surface_temperature_average': 57.8}
# {'date': '2018-12-17', 'surface_temperature_average': None}
# {'date': '2018-12-18', 'surface_temperature_average': None}
# {'date': '2018-12-19', 'surface_temperature_average': None}
# {'date': '2018-12-20', 'surface_temperature_average': None}
# {'date': '2018-12-21', 'surface_temperature_average': 46.0}
# {'date': '2018-12-22', 'surface_temperature_average': None}
# {'date': '2018-12-23', 'surface_temperature_average': None}
# {'date': '2018-12-24', 'surface_temperature_average': 32.0}
# {'date': '2018-12-25', 'surface_temperature_average': 54.0}
# {'date': '2018-12-26', 'surface_temperature_average': None}
# {'date': '2018-12-27', 'surface_temperature_average': 62.75}
# {'date': '2018-12-28', 'surface_temperature_average': None}
# {'date': '2018-12-29', 'surface_temperature_average': None}
# {'date': '2018-12-30', 'surface_temperature_average': None}
# {'date': '2018-12-31', 'surface_temperature_average': None}

# %%
# i. Find the top 10 records with the lowest GHI.

cursor = db.climate.aggregate([
    {"$lookup" : {
        "from" : "hotspot",
        "localField": "_id",
        "foreignField": "foreign_key",
        "as": "from_hotspot_historic"
        }},
    {"$sort" : {"GHI_w/m2":1}},
    {"$limit" : 10 }
    ])

cursor = db.climate.find().sort("GHI_w/m2").limit(10)

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('60a3c9191b38980f0d0c6880'),
#  'air_temperature_celcius': 5,
#  'date': '2018-08-02',
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
#
#
# {'GHI_w/m2': 48,
#  '_id': ObjectId('60a3c9191b38980f0d0c685f'),
#  'air_temperature_celcius': 5,
#  'date': '2018-06-30',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
#
#
# {'GHI_w/m2': 49,
#  '_id': ObjectId('60a3c9191b38980f0d0c6860'),
#  'air_temperature_celcius': 5,
#  'date': '2018-07-01',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
#
#
# {'GHI_w/m2': 56,
#  '_id': ObjectId('60a3c9191b38980f0d0c686a'),
#  'air_temperature_celcius': 6,
#  'date': '2018-07-11',
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
#
#
# {'GHI_w/m2': 57,
#  '_id': ObjectId('60a3c9191b38980f0d0c686e'),
#  'air_temperature_celcius': 6,
#  'date': '2018-07-15',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
#
#
# {'GHI_w/m2': 60,
#  '_id': ObjectId('60a3c9191b38980f0d0c6861'),
#  'air_temperature_celcius': 6,
#  'date': '2018-07-02',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
#
#
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a3c9191b38980f0d0c687f'),
#  'air_temperature_celcius': 7,
#  'date': '2018-08-01',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
#
#
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a3c9191b38980f0d0c6873'),
#  'air_temperature_celcius': 7,
#  'date': '2018-07-20',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
#
#
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a3c9191b38980f0d0c687e'),
#  'air_temperature_celcius': 7,
#  'date': '2018-07-31',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
#
#
# {'GHI_w/m2': 66,
#  '_id': ObjectId('60a3c9191b38980f0d0c6891'),
#  'air_temperature_celcius': 7,
#  'date': '2018-08-19',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %%
# j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.

cursor = db.climate.aggregate([
    {"$lookup" : {
        "from" : "hotspot",
        "localField": "date",
        "foreignField": "date",
        "as": "from_hotspot_historic"
        }},
    {"$addFields" : {
        "check" : {"$toDouble": {"$substr": ["$precipitation ", 1, 4]}}
        }},
    {"$match": {
        "$and":[{'precipitation ': {"$regex" : "G$", "$options":"$i"}}, 
                {"check" : {"$gte":0.20, "$lte":0.35}}
               ]}},
    {"$project" : {"check":0, "from_hotspot_historic":0}}
    ])

for i in cursor:
    pprint(i)
    print('\n')
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('60a3c9191b38980f0d0c67b7'),
#  'air_temperature_celcius': 19,
#  'date': '2018-01-13',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
#
#
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60a3c9191b38980f0d0c6802'),
#  'air_temperature_celcius': 17,
#  'date': '2018-03-29',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
#
#
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60a3c9191b38980f0d0c6818'),
#  'air_temperature_celcius': 20,
#  'date': '2018-04-20',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
#
#
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60a3c9191b38980f0d0c681e'),
#  'air_temperature_celcius': 11,
#  'date': '2018-04-26',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
#
#
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60a3c9191b38980f0d0c683d'),
#  'air_temperature_celcius': 14,
#  'date': '2018-05-27',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.35G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
#
#
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60a3c9191b38980f0d0c6840'),
#  'air_temperature_celcius': 8,
#  'date': '2018-05-30',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
#
#
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60a3c9191b38980f0d0c6862'),
#  'air_temperature_celcius': 11,
#  'date': '2018-07-03',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
#
#
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60a3c9191b38980f0d0c687a'),
#  'air_temperature_celcius': 11,
#  'date': '2018-07-27',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
#
#
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60a3c9191b38980f0d0c6884'),
#  'air_temperature_celcius': 9,
#  'date': '2018-08-06',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
#
#
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60a3c9191b38980f0d0c6898'),
#  'air_temperature_celcius': 11,
#  'date': '2018-08-26',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
#
#
# {'GHI_w/m2': 75,
#  '_id': ObjectId('60a3c9191b38980f0d0c68a2'),
#  'air_temperature_celcius': 8,
#  'date': '2018-09-05',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
#
#
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60a3c9191b38980f0d0c68a4'),
#  'air_temperature_celcius': 10,
#  'date': '2018-09-07',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
#
#
# {'GHI_w/m2': 97,
#  '_id': ObjectId('60a3c9191b38980f0d0c68ac'),
#  'air_temperature_celcius': 11,
#  'date': '2018-09-15',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
#
#
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60a3c9191b38980f0d0c68c0'),
#  'air_temperature_celcius': 12,
#  'date': '2018-10-05',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
#
#
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60a3c9191b38980f0d0c68d8'),
#  'air_temperature_celcius': 17,
#  'date': '2018-10-29',
#  'max_wind_speed': 27.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
#
#
# {'GHI_w/m2': 100,
#  '_id': ObjectId('60a3c9191b38980f0d0c68d9'),
#  'air_temperature_celcius': 11,
#  'date': '2018-10-30',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
#
#
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a3c9191b38980f0d0c68ea'),
#  'air_temperature_celcius': 18,
#  'date': '2018-11-16',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
#
#
# {'GHI_w/m2': 151,
#  '_id': ObjectId('60a3c9191b38980f0d0c68eb'),
#  'air_temperature_celcius': 19,
#  'date': '2018-11-17',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
#
#
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a3c9191b38980f0d0c68f8'),
#  'air_temperature_celcius': 26,
#  'date': '2018-11-30',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
